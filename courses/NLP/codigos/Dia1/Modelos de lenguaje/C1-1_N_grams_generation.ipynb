# %% [markdown]
# **MODELO N-GRAMS**
#
#
# ---
#
# Crearemos dos tipos de modelos N-Grams en esta sección: un modelo de caracteres N-Grams y un modelo de palabras N-Gram.
#
# Personajes Modelo N-Grams
# En esta sección, se explica cómo crear un modelo N-Gram de caracteres simples. En la siguiente sección, cómo implementar el modelo de palabra N-Gram.

# %%
import nltk
import numpy as np
import random
import string

import bs4 as bs
import urllib.request
import re

# %% [markdown]
# **1. Obtención y normalización del texto**
#
#
# Usaremos el artículo de Wikipedia sobre Tenis para crear nuestro corpus. El siguiente script recupera el artículo de Wikipedia y extrae todos los párrafos del texto del artículo. Por último, el texto se convierte a minúsculas para facilitar su procesamiento.

# %%
raw_html = urllib.request.urlopen('https://en.wikipedia.org/wiki/Tennis')
raw_html = raw_html.read()

article_html = bs.BeautifulSoup(raw_html, 'lxml')
article_paragraphs = article_html.find_all('p')
article_text=""

for para in article_paragraphs:
    article_text += para.text

article_text = article_text.lower()
article_text = re.sub(r'[^A-Za-z. ]', '', article_text)

# %% [markdown]
# **3. Creación de N-grams**
# Hemos preprocesado nuestro conjunto de datos y ahora es el momento de crear un modelo de N-Grams. Crearemos un modelo de trigrama de personajes como diccionario ngrams.
#
# Las claves de este diccionario serán los trigramas de caracteres de nuestro corpus y los valores serán los caracteres que aparecen junto a los trigramas. A continuación, dado que estamos creando N-Gram de tres caracteres, declaramos una variable chars. Después de eso, iteramos a través de todos los caracteres de nuestro corpus, comenzando por el cuarto carácter.
#
# A continuación, dentro del ciclo, extraemos el trigrama filtrando los siguientes tres caracteres. El trigrama se almacena en el seq variable. Luego verificamos si el trigrama existe en el diccionario. Si no existe en el ngrams diccionario agregamos el trigrama al diccionario. Después de eso, asignamos una lista vacía como valor al trigrama. Finalmente, el carácter que existe después del trigrama se agrega como valor a la lista.

# %%
ngrams = {}
chars = 4

for i in range(len(article_text)-chars):
    seq = article_text[i:i+chars]
    print(seq)
    if seq not in ngrams.keys():
        ngrams[seq] = []
    ngrams[seq].append(article_text[i+chars])
# Out:
# Streaming output truncated to the last 5000 lines.
# r fo
#  for
# for
# or t
# r th
#  the
# the
# he y
# e ye
#  yea
# year
# ears
# ars
# rs
# s  t
#   th
#  thr
# thro
# hrou
# roug
# ough
# ugh
# gh .
# h .
#  . t
# . te
#  ten
# tenn
# enni
# nnis
# nis
# is h
# s hi
#  his
# hist
# isto
# stor
# tori
# oria
# rian
# ian
# an a
# n an
#  and
# and
# nd j
# d jo
#  jou
# jour
# ourn
# urna
# rnal
# nali
# alis
# list
# ist
# st b
# t bu
#  bud
# bud
# ud c
# d co
#  col
# coll
# olli
# llin
# lins
# ins
# ns h
# s ha
#  has
# has
# as c
# s ca
#  cal
# call
# alle
# lled
# led
# ed n
# d na
#  nav
# navr
# avra
# vrat
# rati
# atil
# tilo
# ilov
# lova
# ova
# va a
# a ar
#  arg
# argu
# rgua
# guab
# uabl
# ably
# bly
# ly t
# y th
#  the
# the
# he g
# e gr
#  gre
# grea
# reat
# eate
# ates
# test
# est
# st p
# t pl
#  pla
# play
# laye
# ayer
# yer
# er o
# r of
#  of
# of a
# f al
#  all
# all
# ll t
# l ti
#  tim
# time
# ime.
# me.
# e. b
# . bi
#  bil
# bill
# illi
# llie
# lie
# ie j
# e je
#  jea
# jean
# ean
# an k
# n ki
#  kin
# king
# ing
# ng s
# g sa
#  sai
# said
# aid
# id a
# d ab
#  abo
# abou
# bout
# out
# ut n
# t na
#  nav
# navr
# avra
# vrat
# rati
# atil
# tilo
# ilov
# lova
# ova
# va i
# a in
#  in
# in
# n  s
#   sh
#  she
# shes
# hes
# es t
# s th
#  the
# the
# he g
# e gr
#  gre
# grea
# reat
# eate
# ates
# test
# est
# st s
# t si
#  sin
# sing
# ingl
# ngle
# gles
# les
# es d
# s do
#  dou
# doub
# oubl
# uble
# bles
# les
# es a
# s an
#  and
# and
# nd m
# d mi
#  mix
# mixe
# ixed
# xed
# ed d
# d do
#  dou
# doub
# oubl
# uble
# bles
# les
# es p
# s pl
#  pla
# play
# laye
# ayer
# yer
# er w
# r wh
#  who
# whos
# hos
# os e
# s ev
#  eve
# ever
# ver
# er l
# r li
#  liv
# live
# ived
# ved.
# ed.i
# d.in
# .in
# in
# n  a
#   a
#  a t
# a te
#  ten
# tenn
# enni
# nnis
# nis.
# is.c
# s.co
# .com
# com
# om p
# m pa
#  pan
# pane
# anel
# nel
# el s
# l se
#  sel
# sele
# elec
# lect
# ecte
# cted
# ted
# ed s
# d se
#  ser
# sere
# eren
# rena
# ena
# na w
# a wi
#  wil
# will
# illi
# llia
# liam
# iams
# ams
# ms a
# s as
#  as
# as t
# s th
#  the
# the
# he g
# e gr
#  gre
# grea
# reat
# eate
# ates
# test
# est
# st f
# t fe
#  fem
# fema
# emal
# male
# ale
# le t
# e te
#  ten
# tenn
# enni
# nnis
# nis
# is p
# s pl
#  pla
# play
# laye
# ayer
# yer
# er i
# r in
#  in
# in t
# n th
#  the
# the
# he o
# e op
#  ope
# open
# pen
# en e
# n er
#  era
# era.
# ra.
# a. i
# . in
#  in
# in m
# n ma
#  may
# may
# ay
# y  t
#   th
#  the
# the
# he t
# e te
#  ten
# tenn
# enni
# nnis
# nis
# is c
# s ch
#  cha
# chan
# hann
# anne
# nnel
# nel
# el r
# l ra
#  ran
# rank
# anke
# nked
# ked
# ed w
# d wi
#  wil
# will
# illi
# llia
# liam
# iams
# ams
# ms a
# s as
#  as
# as t
# s th
#  the
# the
# he g
# e gr
#  gre
# grea
# reat
# eate
# ates
# test
# est
# st f
# t fe
#  fem
# fema
# emal
# male
# ale
# le t
# e te
#  ten
# tenn
# enni
# nnis
# nis
# is p
# s pl
#  pla
# play
# laye
# ayer
# yer
# er o
# r of
#  of
# of a
# f al
#  all
# all
# ll t
# l ti
#  tim
# time
# ime.
# me.i
# e.in
# .in
# in m
# n mo
#  mos
# most
# ost
# st p
# t pr
#  pro
# prof
# rofe
# ofes
# fess
# essi
# ssio
# sion
# iona
# onal
# nal
# al p
# l pl
#  pla
# play
# lay
# ay a
# y an
#  and
# and
# nd s
# d so
#  som
# some
# ome
# me a
# e am
#  ama
# amat
# mate
# ateu
# teur
# eur
# ur c
# r co
#  com
# comp
# ompe
# mpet
# peti
# etit
# titi
# itio
# tion
# ion
# on t
# n th
#  the
# ther
# here
# ere
# re i
# e is
#  is
# is a
# s an
#  an
# an o
# n of
#  off
# offi
# ffic
# fici
# icia
# ciat
# iati
# atin
# ting
# ing
# ng h
# g he
#  hea
# head
# ead
# ad j
# d ju
#  jud
# judg
# udge
# dge
# ge o
# e or
#  or
# or c
# r ch
#  cha
# chai
# hair
# air
# ir u
# r um
#  ump
# umpi
# mpir
# pire
# ire
# re u
# e us
#  usu
# usua
# sual
# uall
# ally
# lly
# ly r
# y re
#  ref
# refe
# efer
# ferr
# erre
# rred
# red
# ed t
# d to
#  to
# to s
# o si
#  sim
# simp
# impl
# mply
# ply
# ly a
# y as
#  as
# as t
# s th
#  the
# the
# he u
# e um
#  ump
# umpi
# mpir
# pire
# ire
# re w
# e wh
#  who
# who
# ho s
# o si
#  sit
# sits
# its
# ts i
# s in
#  in
# in a
# n a
#  a r
# a ra
#  rai
# rais
# aise
# ised
# sed
# ed c
# d ch
#  cha
# chai
# hair
# air
# ir t
# r to
#  to
# to o
# o on
#  one
# one
# ne s
# e si
#  sid
# side
# ide
# de o
# e of
#  of
# of t
# f th
#  the
# the
# he c
# e co
#  cou
# cour
# ourt
# urt.
# rt.
# t. t
# . th
#  the
# the
# he u
# e um
#  ump
# umpi
# mpir
# pire
# ire
# re h
# e ha
#  has
# has
# as a
# s ab
#  abs
# abso
# bsol
# solu
# olut
# lute
# ute
# te a
# e au
#  aut
# auth
# utho
# thor
# hori
# orit
# rity
# ity
# ty t
# y to
#  to
# to m
# o ma
#  mak
# make
# ake
# ke f
# e fa
#  fac
# fact
# actu
# ctua
# tual
# ual
# al d
# l de
#  det
# dete
# eter
# term
# ermi
# rmin
# mina
# inat
# nati
# atio
# tion
# ions
# ons.
# ns.
# s. t
# . th
#  the
# the
# he u
# e um
#  ump
# umpi
# mpir
# pire
# ire
# re m
# e ma
#  may
# may
# ay b
# y be
#  be
# be a
# e as
#  ass
# assi
# ssis
# sist
# iste
# sted
# ted
# ed b
# d by
#  by
# by l
# y li
#  lin
# line
# ine
# ne j
# e ju
#  jud
# judg
# udge
# dges
# ges
# es w
# s wh
#  who
# who
# ho d
# o de
#  det
# dete
# eter
# term
# ermi
# rmin
# mine
# ine
# ne w
# e wh
#  whe
# whet
# heth
# ethe
# ther
# her
# er t
# r th
#  the
# the
# he b
# e ba
#  bal
# ball
# all
# ll h
# l ha
#  has
# has
# as l
# s la
#  lan
# land
# ande
# nded
# ded
# ed w
# d wi
#  wit
# with
# ithi
# thin
# hin
# in t
# n th
#  the
# the
# he r
# e re
#  req
# requ
# equi
# quir
# uire
# ired
# red
# ed p
# d pa
#  par
# part
# art
# rt o
# t of
#  of
# of t
# f th
#  the
# the
# he c
# e co
#  cou
# cour
# ourt
# urt
# rt a
# t an
#  and
# and
# nd w
# d wh
#  who
# who
# ho a
# o al
#  als
# also
# lso
# so c
# o ca
#  cal
# call
# all
# ll f
# l fo
#  foo
# foot
# oot
# ot f
# t fa
#  fau
# faul
# ault
# ults
# lts.
# ts.
# s. t
# . th
#  the
# ther
# here
# ere
# re a
# e al
#  als
# also
# lso
# so m
# o ma
#  may
# may
# ay b
# y be
#  be
# be a
# e a
#  a n
# a ne
#  net
# net
# et j
# t ju
#  jud
# judg
# udge
# dge
# ge w
# e wh
#  who
# who
# ho d
# o de
#  det
# dete
# eter
# term
# ermi
# rmin
# mine
# ines
# nes
# es w
# s wh
#  whe
# whet
# heth
# ethe
# ther
# her
# er t
# r th
#  the
# the
# he b
# e ba
#  bal
# ball
# all
# ll h
# l ha
#  has
# has
# as t
# s to
#  tou
# touc
# ouch
# uche
# ched
# hed
# ed t
# d th
#  the
# the
# he n
# e ne
#  net
# net
# et d
# t du
#  dur
# duri
# urin
# ring
# ing
# ng s
# g se
#  ser
# serv
# ervi
# rvic
# vice
# ice.
# ce.
# e. t
# . th
#  the
# the
# he u
# e um
#  ump
# umpi
# mpir
# pire
# ire
# re h
# e ha
#  has
# has
# as t
# s th
#  the
# the
# he r
# e ri
#  rig
# righ
# ight
# ght
# ht t
# t to
#  to
# to o
# o ov
#  ove
# over
# verr
# erru
# rrul
# rule
# ule
# le a
# e a
#  a l
# a li
#  lin
# line
# ine
# ne j
# e ju
#  jud
# judg
# udge
# dge
# ge o
# e or
#  or
# or a
# r a
#  a n
# a ne
#  net
# net
# et j
# t ju
#  jud
# judg
# udge
# dge
# ge i
# e if
#  if
# if t
# f th
#  the
# the
# he u
# e um
#  ump
# umpi
# mpir
# pire
# ire
# re i
# e is
#  is
# is s
# s su
#  sur
# sure
# ure
# re t
# e th
#  tha
# that
# hat
# at a
# t a
#  a c
# a cl
#  cle
# clea
# lear
# ear
# ar m
# r mi
#  mis
# mist
# ista
# stak
# take
# ake
# ke h
# e ha
#  has
# has
# as b
# s be
#  bee
# been
# een
# en m
# n ma
#  mad
# made
# ade.
# de.i
# e.in
# .in
# in p
# n pa
#  pas
# past
# ast
# st t
# t to
#  tou
# tour
# ourn
# urna
# rnam
# name
# amen
# ment
# ents
# nts
# ts l
# s li
#  lin
# line
# ine
# ne j
# e ju
#  jud
# judg
# udge
# dges
# ges
# es t
# s ta
#  tas
# task
# aske
# sked
# ked
# ed w
# d wi
#  wit
# with
# ith
# th c
# h ca
#  cal
# call
# alli
# llin
# ling
# ing
# ng t
# g th
#  the
# the
# he s
# e se
#  ser
# serv
# erve
# rve
# ve w
# e we
#  wer
# were
# ere
# re s
# e so
#  som
# some
# omet
# meti
# etim
# time
# imes
# mes
# es a
# s as
#  ass
# assi
# ssis
# sist
# iste
# sted
# ted
# ed b
# d by
#  by
# by e
# y el
#  ele
# elec
# lect
# ectr
# ctro
# tron
# roni
# onic
# nic
# ic s
# c se
#  sen
# sens
# enso
# nsor
# sors
# ors
# rs t
# s th
#  tha
# that
# hat
# at b
# t be
#  bee
# beep
# eepe
# eped
# ped
# ed t
# d to
#  to
# to i
# o in
#  ind
# indi
# ndic
# dica
# icat
# cate
# ate
# te a
# e an
#  an
# an o
# n ou
#  out
# outo
# utof
# tofb
# ofbo
# fbou
# boun
# ound
# unds
# nds
# ds s
# s se
#  ser
# serv
# erve
# rve
# ve o
# e on
#  one
# one
# ne s
# e su
#  suc
# such
# uch
# ch s
# h sy
#  sys
# syst
# yste
# stem
# tem
# em w
# m wa
#  was
# was
# as c
# s ca
#  cal
# call
# alle
# lled
# led
# ed c
# d cy
#  cyc
# cycl
# yclo
# clop
# lops
# ops.
# ps.
# s. c
# . cy
#  cyc
# cycl
# yclo
# clop
# lops
# ops
# ps h
# s ha
#  has
# has
# as s
# s si
#  sin
# sinc
# ince
# nce
# ce l
# e la
#  lar
# larg
# arge
# rgel
# gely
# ely
# ly b
# y be
#  bee
# been
# een
# en r
# n re
#  rep
# repl
# epla
# plac
# lace
# aced
# ced
# ed b
# d by
#  by
# by t
# y th
#  the
# the
# he h
# e ha
#  haw
# hawk
# awke
# wkey
# keye
# eye
# ye s
# e sy
#  sys
# syst
# yste
# stem
# tem.
# em.
# m. i
# . in
#  in
# in p
# n pr
#  pro
# prof
# rofe
# ofes
# fess
# essi
# ssio
# sion
# iona
# onal
# nal
# al t
# l to
#  tou
# tour
# ourn
# urna
# rnam
# name
# amen
# ment
# ents
# nts
# ts u
# s us
#  usi
# usin
# sing
# ing
# ng t
# g th
#  thi
# this
# his
# is s
# s sy
#  sys
# syst
# yste
# stem
# tem
# em p
# m pl
#  pla
# play
# laye
# ayer
# yers
# ers
# rs a
# s ar
#  are
# are
# re a
# e al
#  all
# allo
# llow
# lowe
# owed
# wed
# ed t
# d th
#  thr
# thre
# hree
# ree
# ee u
# e un
#  uns
# unsu
# nsuc
# succ
# ucce
# cces
# cess
# essf
# ssfu
# sful
# ful
# ul a
# l ap
#  app
# appe
# ppea
# peal
# eals
# als
# ls p
# s pe
#  per
# per
# er s
# r se
#  set
# set
# et p
# t pl
#  plu
# plus
# lus
# us o
# s on
#  one
# one
# ne a
# e ad
#  add
# addi
# ddit
# diti
# itio
# tion
# iona
# onal
# nal
# al a
# l ap
#  app
# appe
# ppea
# peal
# eal
# al i
# l in
#  in
# in t
# n th
#  the
# the
# he t
# e ti
#  tie
# tieb
# iebr
# ebre
# brea
# reak
# eak
# ak t
# k to
#  to
# to c
# o ch
#  cha
# chal
# hall
# alle
# llen
# leng
# enge
# nge
# ge c
# e cl
#  clo
# clos
# lose
# ose
# se l
# e li
#  lin
# line
# ine
# ne c
# e ca
#  cal
# call
# alls
# lls
# ls b
# s by
#  by
# by m
# y me
#  mea
# mean
# eans
# ans
# ns o
# s of
#  of
# of a
# f an
#  an
# an e
# n el
#  ele
# elec
# lect
# ectr
# ctro
# tron
# roni
# onic
# nic
# ic r
# c re
#  rev
# revi
# evie
# view
# iew.
# ew.
# w. t
# . th
#  the
# the
# he u
# e us
#  us
# us o
# s op
#  ope
# open
# pen
# en m
# n mi
#  mia
# miam
# iami
# ami
# mi m
# i ma
#  mas
# mast
# aste
# ster
# ters
# ers
# rs u
# s us
#  us
# us o
# s op
#  ope
# open
# pen
# en s
# n se
#  ser
# seri
# erie
# ries
# ies
# es a
# s an
#  and
# and
# nd w
# d wo
#  wor
# worl
# orld
# rld
# ld t
# d te
#  tea
# team
# eam
# am t
# m te
#  ten
# tenn
# enni
# nnis
# nis
# is s
# s st
#  sta
# star
# tart
# arte
# rted
# ted
# ed u
# d us
#  usi
# usin
# sing
# ing
# ng t
# g th
#  thi
# this
# his
# is c
# s ch
#  cha
# chal
# hall
# alle
# llen
# leng
# enge
# nge
# ge s
# e sy
#  sys
# syst
# yste
# stem
# tem
# em i
# m in
#  in
# in
# n  a
#   an
#  and
# and
# nd t
# d th
#  the
# the
# he a
# e au
#  aus
# aust
# ustr
# stra
# tral
# rali
# alia
# lian
# ian
# an o
# n op
#  ope
# open
# pen
# en a
# n an
#  and
# and
# nd w
# d wi
#  wim
# wimb
# imbl
# mble
# bled
# ledo
# edon
# don
# on i
# n in
#  int
# intr
# ntro
# trod
# rodu
# oduc
# duce
# uced
# ced
# ed t
# d th
#  the
# the
# he s
# e sy
#  sys
# syst
# yste
# stem
# tem
# em i
# m in
#  in
# in .
# n .
#  . i
# . in
#  in
# in c
# n cl
#  cla
# clay
# layc
# ayco
# ycou
# cour
# ourt
# urt
# rt m
# t ma
#  mat
# matc
# atch
# tche
# ches
# hes
# es s
# s su
#  suc
# such
# uch
# ch a
# h as
#  as
# as a
# s at
#  at
# at t
# t th
#  the
# the
# he f
# e fr
#  fre
# fren
# renc
# ench
# nch
# ch o
# h op
#  ope
# open
# pen
# en a
# n a
#  a c
# a ca
#  cal
# call
# all
# ll m
# l ma
#  may
# may
# ay b
# y be
#  be
# be q
# e qu
#  que
# ques
# uest
# esti
# stio
# tion
# ione
# oned
# ned
# ed b
# d by
#  by
# by r
# y re
#  ref
# refe
# efer
# fere
# eren
# renc
# ence
# nce
# ce t
# e to
#  to
# to t
# o th
#  the
# the
# he m
# e ma
#  mar
# mark
# ark
# rk l
# k le
#  lef
# left
# eft
# ft b
# t by
#  by
# by t
# y th
#  the
# the
# he b
# e ba
#  bal
# ball
# alls
# lls
# ls i
# s im
#  imp
# impa
# mpac
# pact
# act
# ct o
# t on
#  on
# on t
# n th
#  the
# the
# he c
# e co
#  cou
# cour
# ourt
# urt
# rt s
# t su
#  sur
# surf
# urfa
# rfac
# face
# ace.
# ce.t
# e.th
# .the
# the
# he r
# e re
#  ref
# refe
# efer
# fere
# eree
# ree
# ee w
# e wh
#  who
# who
# ho i
# o is
#  is
# is u
# s us
#  usu
# usua
# sual
# uall
# ally
# lly
# ly l
# y lo
#  loc
# loca
# ocat
# cate
# ated
# ted
# ed o
# d of
#  off
# off
# ff t
# f th
#  the
# the
# he c
# e co
#  cou
# cour
# ourt
# urt
# rt i
# t is
#  is
# is t
# s th
#  the
# the
# he f
# e fi
#  fin
# fina
# inal
# nal
# al a
# l au
#  aut
# auth
# utho
# thor
# hori
# orit
# rity
# ity
# ty a
# y ab
#  abo
# abou
# bout
# out
# ut t
# t te
#  ten
# tenn
# enni
# nnis
# nis
# is r
# s ru
#  rul
# rule
# ules
# les.
# es.
# s. w
# . wh
#  whe
# when
# hen
# en c
# n ca
#  cal
# call
# alle
# lled
# led
# ed t
# d to
#  to
# to t
# o th
#  the
# the
# he c
# e co
#  cou
# cour
# ourt
# urt
# rt b
# t by
#  by
# by a
# y a
#  a p
# a pl
#  pla
# play
# laye
# ayer
# yer
# er o
# r or
#  or
# or t
# r te
#  tea
# team
# eam
# am c
# m ca
#  cap
# capt
# apta
# ptai
# tain
# ain
# in t
# n th
#  the
# the
# he r
# e re
#  ref
# refe
# efer
# fere
# eree
# ree
# ee m
# e ma
#  may
# may
# ay o
# y ov
#  ove
# over
# verr
# erru
# rrul
# rule
# ule
# le t
# e th
#  the
# the
# he u
# e um
#  ump
# umpi
# mpir
# pire
# ires
# res
# es d
# s de
#  dec
# deci
# ecis
# cisi
# isio
# sion
# ion
# on i
# n if
#  if
# if t
# f th
#  the
# the
# he t
# e te
#  ten
# tenn
# enni
# nnis
# nis
# is r
# s ru
#  rul
# rule
# ules
# les
# es w
# s we
#  wer
# were
# ere
# re v
# e vi
#  vio
# viol
# iola
# olat
# late
# ated
# ted
# ed q
# d qu
#  que
# ques
# uest
# esti
# stio
# tion
# ion
# on o
# n of
#  of
# of l
# f la
#  law
# law
# aw b
# w bu
#  but
# but
# ut m
# t ma
#  may
# may
# ay n
# y no
#  not
# not
# ot c
# t ch
#  cha
# chan
# hang
# ange
# nge
# ge t
# e th
#  the
# the
# he u
# e um
#  ump
# umpi
# mpir
# pire
# ires
# res
# es d
# s de
#  dec
# deci
# ecis
# cisi
# isio
# sion
# ion
# on o
# n on
#  on
# on a
# n a
#  a q
# a qu
#  que
# ques
# uest
# esti
# stio
# tion
# ion
# on o
# n of
#  of
# of f
# f fa
#  fac
# fact
# act.
# ct.
# t. i
# . if
#  if
# if h
# f ho
#  how
# howe
# owev
# weve
# ever
# ver
# er t
# r th
#  the
# the
# he r
# e re
#  ref
# refe
# efer
# fere
# eree
# ree
# ee i
# e is
#  is
# is o
# s on
#  on
# on t
# n th
#  the
# the
# he c
# e co
#  cou
# cour
# ourt
# urt
# rt d
# t du
#  dur
# duri
# urin
# ring
# ing
# ng p
# g pl
#  pla
# play
# lay
# ay t
# y th
#  the
# the
# he r
# e re
#  ref
# refe
# efer
# fere
# eree
# ree
# ee m
# e ma
#  may
# may
# ay o
# y ov
#  ove
# over
# verr
# erru
# rrul
# rule
# ule
# le t
# e th
#  the
# the
# he u
# e um
#  ump
# umpi
# mpir
# pire
# ires
# res
# es d
# s de
#  dec
# deci
# ecis
# cisi
# isio
# sion
# ion.
# on.
# n. t
# . th
#  thi
# this
# his
# is w
# s wo
#  wou
# woul
# ould
# uld
# ld o
# d on
#  onl
# only
# nly
# ly h
# y ha
#  hap
# happ
# appe
# ppen
# pen
# en i
# n in
#  in
# in d
# n da
#  dav
# davi
# avis
# vis
# is c
# s cu
#  cup
# cup
# up o
# p or
#  or
# or f
# r fe
#  fed
# fed
# ed c
# d cu
#  cup
# cup
# up m
# p ma
#  mat
# matc
# atch
# tche
# ches
# hes
# es n
# s no
#  not
# not
# ot a
# t at
#  at
# at t
# t th
#  the
# the
# he w
# e wo
#  wor
# worl
# orld
# rld
# ld g
# d gr
#  gro
# grou
# roup
# oup
# up l
# p le
#  lev
# leve
# evel
# vel
# el w
# l wh
#  whe
# when
# hen
# en a
# n a
#  a c
# a ch
#  cha
# chai
# hair
# air
# ir u
# r um
#  ump
# umpi
# mpir
# pire
# ire
# re f
# e fr
#  fro
# from
# rom
# om a
# m a
#  a n
# a no
#  non
# nonn
# onne
# nneu
# neut
# eutr
# utra
# tral
# ral
# al c
# l co
#  cou
# coun
# ount
# untr
# ntry
# try
# ry i
# y is
#  is
# is i
# s in
#  in
# in t
# n th
#  the
# the
# he c
# e ch
#  cha
# chai
# hair
# air.
# ir.i
# r.in
# .in
# in t
# n te
#  ten
# tenn
# enni
# nnis
# nis
# is a
# s a
#  a j
# a ju
#  jun
# juni
# unio
# nior
# ior
# or i
# r is
#  is
# is a
# s a
#  a p
# a pl
#  pla
# play
# laye
# ayer
# yer
# er u
# r un
#  und
# unde
# nder
# der
# er
# r  w
#   wh
#  who
# who
# ho i
# o is
#  is
# is s
# s st
#  sti
# stil
# till
# ill
# ll l
# l le
#  leg
# lega
# egal
# gall
# ally
# lly
# ly p
# y pr
#  pro
# prot
# rote
# otec
# tect
# ecte
# cted
# ted
# ed b
# d by
#  by
# by a
# y a
#  a p
# a pa
#  par
# pare
# aren
# rent
# ent
# nt o
# t or
#  or
# or g
# r gu
#  gua
# guar
# uard
# ardi
# rdia
# dian
# ian.
# an.
# n. p
# . pl
#  pla
# play
# laye
# ayer
# yers
# ers
# rs o
# s on
#  on
# on t
# n th
#  the
# the
# he m
# e ma
#  mai
# main
# ain
# in a
# n ad
#  adu
# adul
# dult
# ult
# lt t
# t to
#  tou
# tour
# our
# ur w
# r wh
#  who
# who
# ho a
# o ar
#  are
# are
# re u
# e un
#  und
# unde
# nder
# der
# er
# r  m
#   mu
#  mus
# must
# ust
# st h
# t ha
#  hav
# have
# ave
# ve d
# e do
#  doc
# docu
# ocum
# cume
# umen
# ment
# ents
# nts
# ts s
# s si
#  sig
# sign
# igne
# gned
# ned
# ed b
# d by
#  by
# by a
# y a
#  a p
# a pa
#  par
# pare
# aren
# rent
# ent
# nt o
# t or
#  or
# or g
# r gu
#  gua
# guar
# uard
# ardi
# rdia
# dian
# ian.
# an.
# n. t
# . th
#  the
# thes
# hese
# ese
# se p
# e pl
#  pla
# play
# laye
# ayer
# yers
# ers
# rs h
# s ho
#  how
# howe
# owev
# weve
# ever
# ver
# er a
# r ar
#  are
# are
# re s
# e st
#  sti
# stil
# till
# ill
# ll e
# l el
#  eli
# elig
# ligi
# igib
# gibl
# ible
# ble
# le t
# e to
#  to
# to p
# o pl
#  pla
# play
# lay
# ay i
# y in
#  in
# in j
# n ju
#  jun
# juni
# unio
# nior
# ior
# or t
# r to
#  tou
# tour
# ourn
# urna
# rnam
# name
# amen
# ment
# ents
# nts.
# ts.t
# s.th
# .the
# the
# he i
# e in
#  int
# inte
# nter
# tern
# erna
# rnat
# nati
# atio
# tion
# iona
# onal
# nal
# al t
# l te
#  ten
# tenn
# enni
# nnis
# nis
# is f
# s fe
#  fed
# fede
# eder
# dera
# erat
# rati
# atio
# tion
# ion
# on i
# n it
#  itf
# itf
# tf c
# f co
#  con
# cond
# ondu
# nduc
# duct
# ucts
# cts
# ts a
# s a
#  a j
# a ju
#  jun
# juni
# unio
# nior
# ior
# or t
# r to
#  tou
# tour
# our
# ur t
# r th
#  tha
# that
# hat
# at a
# t al
#  all
# allo
# llow
# lows
# ows
# ws j
# s ju
#  jun
# juni
# unio
# nior
# iors
# ors
# rs t
# s to
#  to
# to e
# o es
#  est
# esta
# stab
# tabl
# abli
# blis
# lish
# ish
# sh a
# h a
#  a w
# a wo
#  wor
# worl
# orld
# rld
# ld r
# d ra
#  ran
# rank
# anki
# nkin
# king
# ing
# ng a
# g an
#  and
# and
# nd a
# d an
#  an
# an a
# n as
#  ass
# asso
# ssoc
# soci
# ocia
# ciat
# iati
# atio
# tion
# ion
# on o
# n of
#  of
# of t
# f te
#  ten
# tenn
# enni
# nnis
# nis
# is p
# s pr
#  pro
# prof
# rofe
# ofes
# fess
# essi
# ssio
# sion
# iona
# onal
# nals
# als
# ls a
# s at
#  atp
# atp
# tp o
# p or
#  or
# or w
# r wo
#  wom
# wome
# omen
# mens
# ens
# ns t
# s te
#  ten
# tenn
# enni
# nnis
# nis
# is a
# s as
#  ass
# asso
# ssoc
# soci
# ocia
# ciat
# iati
# atio
# tion
# ion
# on w
# n wt
#  wta
# wta
# ta r
# a ra
#  ran
# rank
# anki
# nkin
# king
# ing.
# ng.
# g. m
# . mo
#  mos
# most
# ost
# st j
# t ju
#  jun
# juni
# unio
# nior
# iors
# ors
# rs w
# s wh
#  who
# who
# ho e
# o en
#  ent
# ente
# nter
# ter
# er t
# r th
#  the
# the
# he i
# e in
#  int
# inte
# nter
# tern
# erna
# rnat
# nati
# atio
# tion
# iona
# onal
# nal
# al c
# l ci
#  cir
# circ
# ircu
# rcui
# cuit
# uit
# it d
# t do
#  do
# do s
# o so
#  so
# so b
# o by
#  by
# by p
# y pr
#  pro
# prog
# rogr
# ogre
# gres
# ress
# essi
# ssin
# sing
# ing
# ng t
# g th
#  thr
# thro
# hrou
# roug
# ough
# ugh
# gh i
# h it
#  itf
# itf
# tf s
# f sa
#  sat
# sate
# atel
# tell
# elli
# llit
# lite
# ite
# te f
# e fu
#  fut
# futu
# utur
# ture
# ure
# re a
# e an
#  and
# and
# nd c
# d ch
#  cha
# chal
# hall
# alle
# llen
# leng
# enge
# nger
# ger
# er t
# r to
#  tou
# tour
# ourn
# urna
# rnam
# name
# amen
# ment
# ents
# nts
# ts b
# s be
#  bef
# befo
# efor
# fore
# ore
# re e
# e en
#  ent
# ente
# nter
# teri
# erin
# ring
# ing
# ng t
# g th
#  the
# the
# he m
# e ma
#  mai
# main
# ain
# in c
# n ci
#  cir
# circ
# ircu
# rcui
# cuit
# uit.
# it.
# t. t
# . th
#  the
# the
# he l
# e la
#  lat
# latt
# atte
# tter
# ter
# er t
# r th
#  thr
# thre
# hree
# ree
# ee c
# e ci
#  cir
# circ
# ircu
# rcui
# cuit
# uits
# its
# ts a
# s al
#  als
# also
# lso
# so h
# o ha
#  hav
# have
# ave
# ve a
# e ad
#  adu
# adul
# dult
# ults
# lts
# ts c
# s co
#  com
# comp
# ompe
# mpet
# peti
# etin
# ting
# ing
# ng i
# g in
#  in
# in t
# n th
#  the
# them
# hem.
# em.
# m. s
# . so
#  som
# some
# ome
# me j
# e ju
#  jun
# juni
# unio
# nior
# iors
# ors
# rs h
# s ho
#  how
# howe
# owev
# weve
# ever
# ver
# er s
# r su
#  suc
# such
# uch
# ch a
# h as
#  as
# as a
# s au
#  aus
# aust
# ustr
# stra
# tral
# rali
# alia
# lian
# ian
# an l
# n ll
#  lle
# lley
# leyt
# eyto
# yton
# ton
# on h
# n he
#  hew
# hewi
# ewit
# witt
# itt
# tt a
# t an
#  and
# and
# nd f
# d fr
#  fre
# fren
# renc
# ench
# nchm
# chma
# hman
# man
# an g
# n ga
#  gal
# gal
# al m
# l mo
#  mon
# monf
# onfi
# nfil
# fils
# ils
# ls h
# s ha
#  hav
# have
# ave
# ve c
# e ca
#  cat
# cata
# atap
# tapu
# apul
# pult
# ulte
# lted
# ted
# ed d
# d di
#  dir
# dire
# irec
# rect
# ectl
# ctly
# tly
# ly f
# y fr
#  fro
# from
# rom
# om t
# m th
#  the
# the
# he j
# e ju
#  jun
# juni
# unio
# nior
# ior
# or t
# r to
#  tou
# tour
# our
# ur t
# r to
#  to
# to t
# o th
#  the
# the
# he a
# e at
#  atp
# atp
# tp t
# p to
#  tou
# tour
# our
# ur b
# r by
#  by
# by d
# y do
#  dom
# domi
# omin
# mina
# inat
# nati
# atin
# ting
# ing
# ng t
# g th
#  the
# the
# he j
# e ju
#  jun
# juni
# unio
# nior
# ior
# or s
# r sc
#  sce
# scen
# cene
# ene
# ne o
# e or
#  or
# or b
# r by
#  by
# by t
# y ta
#  tak
# taki
# akin
# king
# ing
# ng a
# g ad
#  adv
# adva
# dvan
# vant
# anta
# ntag
# tage
# age
# ge o
# e of
#  of
# of o
# f op
#  opp
# oppo
# ppor
# port
# ortu
# rtun
# tuni
# unit
# niti
# itie
# ties
# ies
# es g
# s gi
#  giv
# give
# iven
# ven
# en t
# n to
#  to
# to t
# o th
#  the
# them
# hem
# em t
# m to
#  to
# to p
# o pa
#  par
# part
# arti
# rtic
# tici
# icip
# cipa
# ipat
# pate
# ate
# te i
# e in
#  in
# in p
# n pr
#  pro
# prof
# rofe
# ofes
# fess
# essi
# ssio
# sion
# iona
# onal
# nal
# al t
# l to
#  tou
# tour
# ourn
# urna
# rnam
# name
# amen
# ment
# ents
# nts.
# ts.i
# s.in
# .in
# in
# n  t
#   th
#  the
# the
# he i
# e it
#  itf
# itf
# tf i
# f im
#  imp
# impl
# mple
# plem
# leme
# emen
# ment
# ente
# nted
# ted
# ed a
# d a
#  a n
# a ne
#  new
# new
# ew r
# w ra
#  ran
# rank
# anki
# nkin
# king
# ings
# ngs
# gs s
# s sc
#  sch
# sche
# chem
# heme
# eme
# me t
# e to
#  to
# to e
# o en
#  enc
# enco
# ncou
# cour
# oura
# urag
# rage
# age
# ge g
# e gr
#  gre
# grea
# reat
# eate
# ater
# ter
# er p
# r pa
#  par
# part
# arti
# rtic
# tici
# icip
# cipa
# ipat
# pati
# atio
# tion
# ion
# on i
# n in
#  in
# in d
# n do
#  dou
# doub
# oubl
# uble
# bles
# les
# es b
# s by
#  by
# by c
# y co
#  com
# comb
# ombi
# mbin
# bini
# inin
# ning
# ing
# ng t
# g tw
#  two
# two
# wo r
# o ra
#  ran
# rank
# anki
# nkin
# king
# ings
# ngs
# gs s
# s si
#  sin
# sing
# ingl
# ngle
# gles
# les
# es a
# s an
#  and
# and
# nd d
# d do
#  dou
# doub
# oubl
# uble
# bles
# les
# es i
# s in
#  int
# into
# nto
# to o
# o on
#  one
# one
# ne c
# e co
#  com
# comb
# ombi
# mbin
# bine
# ined
# ned
# ed t
# d ta
#  tal
# tall
# ally
# lly.
# ly.
# y. j
# . ju
#  jun
# juni
# unio
# nior
# ior
# or t
# r to
#  tou
# tour
# ourn
# urna
# rnam
# name
# amen
# ment
# ents
# nts
# ts d
# s do
#  do
# do n
# o no
#  not
# not
# ot o
# t of
#  off
# offe
# ffer
# fer
# er p
# r pr
#  pri
# priz
# rize
# ize
# ze m
# e mo
#  mon
# mone
# oney
# ney
# ey e
# y ex
#  exc
# exce
# xcep
# cept
# ept
# pt f
# t fo
#  for
# for
# or t
# r th
#  the
# the
# he g
# e gr
#  gra
# gran
# rand
# and
# nd s
# d sl
#  sla
# slam
# lam
# am t
# m to
#  tou
# tour
# ourn
# urna
# rnam
# name
# amen
# ment
# ents
# nts
# ts w
# s wh
#  whi
# whic
# hich
# ich
# ch a
# h ar
#  are
# are
# re t
# e th
#  the
# the
# he m
# e mo
#  mos
# most
# ost
# st p
# t pr
#  pre
# pres
# rest
# esti
# stig
# tigi
# igio
# giou
# ious
# ous
# us j
# s ju
#  jun
# juni
# unio
# nior
# ior
# or e
# r ev
#  eve
# even
# vent
# ents
# nts.
# ts.
# s. j
# . ju
#  jun
# juni
# unio
# nior
# iors
# ors
# rs m
# s ma
#  may
# may
# ay e
# y ea
#  ear
# earn
# arn
# rn i
# n in
#  inc
# inco
# ncom
# come
# ome
# me f
# e fr
#  fro
# from
# rom
# om t
# m te
#  ten
# tenn
# enni
# nnis
# nis
# is b
# s by
#  by
# by p
# y pa
#  par
# part
# arti
# rtic
# tici
# icip
# cipa
# ipat
# pati
# atin
# ting
# ing
# ng i
# g in
#  in
# in t
# n th
#  the
# the
# he f
# e fu
#  fut
# futu
# utur
# ture
# ure
# re s
# e sa
#  sat
# sate
# atel
# tell
# elli
# llit
# lite
# ite
# te o
# e or
#  or
# or c
# r ch
#  cha
# chal
# hall
# alle
# llen
# leng
# enge
# nger
# ger
# er t
# r to
#  tou
# tour
# ours
# urs.
# rs.
# s. t
# . to
#  tou
# tour
# ourn
# urna
# rnam
# name
# amen
# ment
# ents
# nts
# ts a
# s ar
#  are
# are
# re b
# e br
#  bro
# brok
# roke
# oken
# ken
# en u
# n up
#  up
# up i
# p in
#  int
# into
# nto
# to d
# o di
#  dif
# diff
# iffe
# ffer
# fere
# eren
# rent
# ent
# nt t
# t ti
#  tie
# tier
# iers
# ers
# rs o
# s of
#  off
# offe
# ffer
# feri
# erin
# ring
# ing
# ng d
# g di
#  dif
# diff
# iffe
# ffer
# fere
# eren
# rent
# ent
# nt a
# t am
#  amo
# amou
# moun
# ount
# unts
# nts
# ts o
# s of
#  of
# of r
# f ra
#  ran
# rank
# anki
# nkin
# king
# ing
# ng p
# g po
#  poi
# poin
# oint
# ints
# nts
# ts c
# s cu
#  cul
# culm
# ulmi
# lmin
# mina
# inat
# nati
# atin
# ting
# ing
# ng w
# g wi
#  wit
# with
# ith
# th g
# h gr
#  gra
# grad
# rade
# ade
# de a
# e a.
#  a.l
# a.le
# .lea
# lead
# eadi
# adin
# ding
# ing
# ng j
# g ju
#  jun
# juni
# unio
# nior
# iors
# ors
# rs a
# s ar
#  are
# are
# re a
# e al
#  all
# allo
# llow
# lowe
# owed
# wed
# ed t
# d to
#  to
# to p
# o pa
#  par
# part
# arti
# rtic
# tici
# icip
# cipa
# ipat
# pate
# ate
# te f
# e fo
#  for
# for
# or t
# r th
#  the
# thei
# heir
# eir
# ir n
# r na
#  nat
# nati
# atio
# tion
# ion
# on i
# n in
#  in
# in t
# n th
#  the
# the
# he j
# e ju
#  jun
# juni
# unio
# nior
# ior
# or f
# r fe
#  fed
# fed
# ed c
# d cu
#  cup
# cup
# up a
# p an
#  and
# and
# nd d
# d da
#  dav
# davi
# avis
# vis
# is c
# s cu
#  cup
# cup
# up c
# p co
#  com
# comp
# ompe
# mpet
# peti
# etit
# titi
# itio
# tion
# ions
# ons.
# ns.
# s. t
# . to
#  to
# to s
# o su
#  suc
# succ
# ucce
# ccee
# ceed
# eed
# ed i
# d in
#  in
# in t
# n te
#  ten
# tenn
# enni
# nnis
# nis
# is o
# s of
#  oft
# ofte
# ften
# ten
# en m
# n me
#  mea
# mean
# eans
# ans
# ns h
# s ha
#  hav
# havi
# avin
# ving
# ing
# ng t
# g to
#  to
# to b
# o be
#  beg
# begi
# egin
# gin
# in p
# n pl
#  pla
# play
# layi
# ayin
# ying
# ing
# ng a
# g at
#  at
# at a
# t a
#  a y
# a yo
#  you
# youn
# oung
# ung
# ng a
# g ag
#  age
# age.
# ge.
# e. t
# . to
#  to
# to f
# o fa
#  fac
# faci
# acil
# cili
# ilit
# lita
# itat
# tate
# ate
# te a
# e an
#  and
# and
# nd n
# d nu
#  nur
# nurt
# urtu
# rtur
# ture
# ure
# re a
# e a
#  a j
# a ju
#  jun
# juni
# unio
# nior
# iors
# ors
# rs g
# s gr
#  gro
# grow
# rowt
# owth
# wth
# th i
# h in
#  in
# in t
# n te
#  ten
# tenn
# enni
# nnis
# nis
# is a
# s al
#  alm
# almo
# lmos
# most
# ost
# st a
# t al
#  all
# all
# ll t
# l te
#  ten
# tenn
# enni
# nnis
# nis
# is p
# s pl
#  pla
# play
# layi
# ayin
# ying
# ing
# ng n
# g na
#  nat
# nati
# atio
# tion
# ions
# ons
# ns h
# s ha
#  hav
# have
# ave
# ve d
# e de
#  dev
# deve
# evel
# velo
# elop
# lope
# oped
# ped
# ed a
# d a
#  a j
# a ju
#  jun
# juni
# unio
# nior
# ior
# or d
# r de
#  dev
# deve
# evel
# velo
# elop
# lopm
# opme
# pmen
# ment
# ent
# nt s
# t sy
#  sys
# syst
# yste
# stem
# tem.
# em.
# m. j
# . ju
#  jun
# juni
# unio
# nior
# iors
# ors
# rs d
# s de
#  dev
# deve
# evel
# velo
# elop
# lop
# op t
# p th
#  the
# thei
# heir
# eir
# ir p
# r pl
#  pla
# play
# lay
# ay t
# y th
#  thr
# thro
# hrou
# roug
# ough
# ugh
# gh a
# h a
#  a r
# a ra
#  ran
# rang
# ange
# nge
# ge o
# e of
#  of
# of t
# f to
#  tou
# tour
# ourn
# urna
# rnam
# name
# amen
# ment
# ents
# nts
# ts o
# s on
#  on
# on a
# n al
#  all
# all
# ll s
# l su
#  sur
# surf
# urfa
# rfac
# face
# aces
# ces
# es a
# s ac
#  acc
# acco
# ccom
# comm
# ommo
# mmod
# moda
# odat
# dati
# atin
# ting
# ing
# ng a
# g al
#  all
# all
# ll d
# l di
#  dif
# diff
# iffe
# ffer
# fere
# eren
# rent
# ent
# nt s
# t st
#  sta
# stan
# tand
# anda
# ndar
# dard
# ards
# rds
# ds o
# s of
#  of
# of p
# f pl
#  pla
# play
# lay.
# ay.
# y. t
# . ta
#  tal
# tale
# alen
# lent
# ente
# nted
# ted
# ed j
# d ju
#  jun
# juni
# unio
# nior
# iors
# ors
# rs m
# s ma
#  may
# may
# ay a
# y al
#  als
# also
# lso
# so r
# o re
#  rec
# rece
# ecei
# ceiv
# eive
# ive
# ve s
# e sp
#  spo
# spon
# pons
# onso
# nsor
# sors
# orsh
# rshi
# ship
# hips
# ips
# ps f
# s fr
#  fro
# from
# rom
# om g
# m go
#  gov
# gove
# over
# vern
# erni
# rnin
# ning
# ing
# ng b
# g bo
#  bod
# bodi
# odie
# dies
# ies
# es o
# s or
#  or
# or p
# r pr
#  pri
# priv
# riva
# ivat
# vate
# ate
# te i
# e in
#  ins
# inst
# nsti
# stit
# titu
# itut
# tuti
# utio
# tion
# ions
# ons.
# ns.m
# s.mu
# .mus
# musc
# uscl
# scle
# cle
# le s
# e st
#  str
# stra
# trai
# rain
# ain
# in i
# n is
#  is
# is o
# s on
#  one
# one
# ne o
# e of
#  of
# of t
# f th
#  the
# the
# he m
# e mo
#  mos
# most
# ost
# st c
# t co
#  com
# comm
# ommo
# mmon
# mon
# on i
# n in
#  inj
# inju
# njur
# juri
# urie
# ries
# ies
# es i
# s in
#  in
# in t
# n te
#  ten
# tenn
# enni
# nnis
# nis.
# is.
# s. w
# . wh
#  whe
# when
# hen
# en a
# n an
#  an
# an i
# n is
#  iso
# isol
# sola
# olat
# late
# ated
# ted
# ed l
# d la
#  lar
# larg
# arge
# rgee
# geen
# eene
# ener
# nerg
# ergy
# rgy
# gy a
# y ap
#  app
# appe
# ppea
# pear
# ears
# ars
# rs d
# s du
#  dur
# duri
# urin
# ring
# ing
# ng t
# g th
#  the
# the
# he m
# e mu
#  mus
# musc
# uscl
# scle
# cle
# le c
# e co
#  con
# cont
# ontr
# ntra
# trac
# ract
# acti
# ctio
# tion
# ion
# on a
# n an
#  and
# and
# nd a
# d at
#  at
# at t
# t th
#  the
# the
# he s
# e sa
#  sam
# same
# ame
# me t
# e ti
#  tim
# time
# ime
# me b
# e bo
#  bod
# body
# ody
# dy w
# y we
#  wei
# weig
# eigh
# ight
# ght
# ht a
# t ap
#  app
# appl
# pply
# ply
# ly h
# y hu
#  hug
# huge
# uge
# ge a
# e am
#  amo
# amou
# moun
# ount
# unt
# nt o
# t of
#  of
# of p
# f pr
#  pre
# pres
# ress
# essu
# ssur
# sure
# ure
# re t
# e to
#  to
# to t
# o th
#  the
# the
# he l
# e le
#  len
# leng
# engt
# ngth
# gthe
# then
# hene
# ened
# ned
# ed m
# d mu
#  mus
# musc
# uscl
# scle
# cle
# le m
# e mu
#  mus
# musc
# uscl
# scle
# cle
# le s
# e st
#  str
# stra
# trai
# rain
# ain
# in c
# n ca
#  can
# can
# an o
# n oc
#  occ
# occu
# ccur
# cur.
# ur.
# r. i
# . in
#  inf
# infl
# nfla
# flam
# lamm
# amma
# mmat
# mati
# atio
# tion
# ion
# on a
# n an
#  and
# and
# nd b
# d bl
#  ble
# blee
# leed
# eedi
# edin
# ding
# ing
# ng a
# g ar
#  are
# are
# re t
# e tr
#  tri
# trig
# rigg
# igge
# gger
# gere
# ered
# red
# ed w
# d wh
#  whe
# when
# hen
# en m
# n mu
#  mus
# musc
# uscl
# scle
# cle
# le s
# e st
#  str
# stra
# trai
# rain
# ain
# in o
# n oc
#  occ
# occu
# ccur
# curs
# urs
# rs w
# s wh
#  whi
# whic
# hich
# ich
# ch c
# h ca
#  can
# can
# an r
# n re
#  res
# resu
# esul
# sult
# ult
# lt i
# t in
#  in
# in r
# n re
#  red
# redn
# edne
# dnes
# ness
# ess
# ss p
# s pa
#  pai
# pain
# ain
# in a
# n an
#  and
# and
# nd s
# d sw
#  swe
# swel
# well
# elli
# llin
# ling
# ing.
# ng.
# g. o
# . ov
#  ove
# over
# veru
# erus
# ruse
# use
# se i
# e is
#  is
# is a
# s al
#  als
# also
# lso
# so c
# o co
#  com
# comm
# ommo
# mmon
# mon
# on i
# n in
#  in
# in t
# n te
#  ten
# tenn
# enni
# nnis
# nis
# is p
# s pl
#  pla
# play
# laye
# ayer
# yers
# ers
# rs o
# s of
#  of
# of a
# f al
#  all
# all
# ll l
# l le
#  lev
# leve
# evel
# vels
# els.
# ls.
# s. m
# . mu
#  mus
# musc
# uscl
# scle
# cle
# le c
# e ca
#  car
# cart
# arti
# rtil
# tila
# ilag
# lage
# age
# ge n
# e ne
#  ner
# nerv
# erve
# rves
# ves
# es b
# s bu
#  bur
# burs
# ursa
# rsae
# sae
# ae l
# e li
#  lig
# liga
# igam
# game
# amen
# ment
# ents
# nts
# ts a
# s an
#  and
# and
# nd t
# d te
#  ten
# tend
# endo
# ndon
# dons
# ons
# ns m
# s ma
#  may
# may
# ay b
# y be
#  be
# be d
# e da
#  dam
# dama
# amag
# mage
# aged
# ged
# ed f
# d fr
#  fro
# from
# rom
# om o
# m ov
#  ove
# over
# veru
# erus
# ruse
# use.
# se.
# e. t
# . th
#  the
# the
# he r
# e re
#  rep
# repe
# epet
# peti
# etit
# titi
# itiv
# tive
# ive
# ve u
# e us
#  use
# use
# se o
# e of
#  of
# of a
# f a
#  a p
# a pa
#  par
# part
# arti
# rtic
# ticu
# icul
# cula
# ular
# lar
# ar m
# r mu
#  mus
# musc
# uscl
# scle
# cle
# le w
# e wi
#  wit
# with
# itho
# thou
# hout
# out
# ut t
# t ti
#  tim
# time
# ime
# me f
# e fo
#  for
# for
# or r
# r re
#  rep
# repa
# epai
# pair
# air
# ir a
# r an
#  and
# and
# nd r
# d re
#  rec
# reco
# ecov
# cove
# over
# very
# ery
# ry i
# y is
#  is
# is t
# s th
#  the
# the
# he m
# e mo
#  mos
# most
# ost
# st c
# t co
#  com
# comm
# ommo
# mmon
# mon
# on c
# n ca
#  cau
# caus
# ause
# use
# se o
# e of
#  of
# of i
# f in
#  inj
# inju
# njur
# jury

# %% [markdown]
# **3. Generación de texto: caracteres_N-grams**
#
# Intentemos ahora generar texto usando los primeros tres caracteres de nuestro corpus como entrada. Los primeros tres caracteres de nuestro corpus son «diez»
#
# En el script primero almacenamos el primer trigrama, es decir ten en el curr_sequence variable. Generaremos un texto de doscientos caracteres, por lo que inicializamos un ciclo que se repite 200 veces. Durante cada iteración, comprobamos si el curr_sequence o el trigrama está en el ngrams diccionario. Si el trigrama no se encuentra en el ngrams diccionario, simplemente salimos del ciclo.
#
# A continuación, el curr_sequence trigrama se pasa como clave para el ngrams diccionario, que devuelve la lista de posibles caracteres siguientes. De la lista de posibles caracteres siguientes, se elige aleatoriamente un índice, que se pasa al possible_chars list para obtener el siguiente carácter del trigrama actual. A continuación, se añade el siguiente carácter al output variable que contiene la salida final.
#
# Finalmente, el curr_sequence se actualiza con el siguiente trigrama del corpus de texto. Si imprime el output variable que contiene doscientos caracteres generados automáticamente, debería ver algo como esto (es importante mencionar que dado que el siguiente carácter se elige al azar, su salida puede ser diferente):

# %%
curr_sequence = article_text[0:chars]
output = curr_sequence
for i in range(200):
    if curr_sequence not in ngrams.keys():
        break
    possible_chars = ngrams[curr_sequence]
    next_char = possible_chars[random.randrange(len(possible_chars))]
    output += next_char
    curr_sequence = output[len(output)-chars:len(output)]

print(output)
# Out:
# tennis court. the set .m high slice rise deline used from the same each player or legal seconds weaving imaged forwarded statest preside of all in the coiled this ceramical found profession which hostines

# %% [markdown]
# **MODELO PALABRA N-GRAMS**
#
# ---
# En el modelo de Words N-Grams, cada palabra del texto se trata como un elemento individual. En esta sección, implementaremos el modelo Words N-Grams y lo usaremos para crear un relleno de texto automático.
#
# El conjunto de datos que vamos a usar es el mismo que usamos en la última sección.
#
# Primero creemos un diccionario que contenga trigramas de palabras como claves y la lista de palabras que aparecen después de los trigramas como valores.

# %%
nltk.download('punkt')
ngrams = {}
words = 3

words_tokens = nltk.word_tokenize(article_text)
for i in range(len(words_tokens)-words):
    seq = ' '.join(words_tokens[i:i+words])
    print(seq)
    if  seq not in ngrams.keys():
        ngrams[seq] = []
    ngrams[seq].append(words_tokens[i+words])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Streaming output truncated to the last 5000 lines.
# entirely to the
# to the front
# the front foot.this
# front foot.this is
# foot.this is sometimes
# is sometimes also
# sometimes also referred
# also referred to
# referred to as
# to as the
# as the square
# the square stance
# square stance .
# stance . one
# . one foot
# one foot is
# foot is positioned
# is positioned closer
# positioned closer to
# closer to the
# to the net
# the net and
# net and ahead
# and ahead of
# ahead of the
# of the other
# the other which
# other which is
# which is behind
# is behind and
# behind and in
# and in line
# in line with
# line with it
# with it .
# it . both
# . both feet
# both feet are
# feet are aligned
# are aligned at
# aligned at a
# at a degree
# a degree angle
# degree angle to
# angle to the
# to the net
# the net .
# net . the
# . the neutral
# the neutral stance
# neutral stance is
# stance is often
# is often taught
# often taught early
# taught early because
# early because it
# because it allows
# it allows beginners
# allows beginners to
# beginners to learn
# to learn about
# learn about shifting
# about shifting weight
# shifting weight and
# weight and rotation
# and rotation of
# rotation of the
# of the body
# the body .
# body . forehands
# . forehands and
# forehands and backhands
# and backhands may
# backhands may be
# may be made
# be made from
# made from it.a
# from it.a competent
# it.a competent tennis
# competent tennis player
# tennis player has
# player has eight
# has eight basic
# eight basic shots
# basic shots in
# shots in his
# in his or
# his or her
# or her repertoire
# her repertoire the
# repertoire the serve
# the serve forehand
# serve forehand backhand
# forehand backhand volley
# backhand volley halfvolley
# volley halfvolley overhead
# halfvolley overhead smash
# overhead smash drop
# smash drop shot
# drop shot and
# shot and lob.a
# and lob.a grip
# lob.a grip is
# grip is a
# is a way
# a way of
# way of holding
# of holding the
# holding the racket
# the racket in
# racket in order
# in order to
# order to hit
# to hit shots
# hit shots during
# shots during a
# during a match
# a match .
# match . the
# . the grip
# the grip affects
# grip affects the
# affects the angle
# the angle of
# angle of the
# of the racket
# the racket face
# racket face when
# face when it
# when it hits
# it hits the
# hits the ball
# the ball and
# ball and influences
# and influences the
# influences the pace
# the pace spin
# pace spin and
# spin and placement
# and placement of
# placement of the
# of the shot
# the shot .
# shot . players
# . players use
# players use various
# use various grips
# various grips during
# grips during play
# during play including
# play including the
# including the continental
# the continental the
# continental the handshake
# the handshake grip
# handshake grip eastern
# grip eastern can
# eastern can be
# can be either
# be either semieastern
# either semieastern or
# semieastern or full
# or full eastern
# full eastern .
# eastern . usually
# . usually used
# usually used for
# used for backhands
# for backhands .
# backhands . and
# . and western
# and western semiwestern
# western semiwestern or
# semiwestern or full
# or full western
# full western usually
# western usually for
# usually for forehand
# for forehand grips
# forehand grips grips
# grips grips .
# grips . most
# . most players
# most players change
# players change grips
# change grips during
# grips during a
# during a match
# a match depending
# match depending on
# depending on what
# on what shot
# what shot they
# shot they are
# they are hitting
# are hitting for
# hitting for example
# for example slice
# example slice shots
# slice shots and
# shots and serves
# and serves call
# serves call for
# call for a
# for a continental
# a continental grip.a
# continental grip.a serve
# grip.a serve or
# serve or more
# or more formally
# more formally a
# formally a service
# a service in
# service in tennis
# in tennis is
# tennis is a
# is a shot
# a shot to
# shot to start
# to start a
# start a point
# a point .
# point . the
# . the serve
# the serve is
# serve is initiated
# is initiated by
# initiated by tossing
# by tossing the
# tossing the ball
# the ball into
# ball into the
# into the air
# the air and
# air and hitting
# and hitting it
# hitting it usually
# it usually near
# usually near the
# near the apex
# the apex of
# apex of its
# of its trajectory
# its trajectory into
# trajectory into the
# into the diagonally
# the diagonally opposite
# diagonally opposite service
# opposite service box
# service box without
# box without touching
# without touching the
# touching the net
# the net .
# net . the
# . the serve
# the serve may
# serve may be
# may be hit
# be hit under
# hit under or
# under or overhand
# or overhand although
# overhand although underhand
# although underhand serving
# underhand serving remains
# serving remains a
# remains a rarity
# a rarity .
# rarity . if
# . if the
# if the ball
# the ball hits
# ball hits the
# hits the net
# the net on
# net on the
# on the first
# the first serve
# first serve and
# serve and bounces
# and bounces over
# bounces over into
# over into the
# into the correct
# the correct diagonal
# correct diagonal box
# diagonal box then
# box then it
# then it is
# it is called
# is called a
# called a let
# a let and
# let and the
# and the server
# the server gets
# server gets two
# gets two more
# two more additional
# more additional serves
# additional serves to
# serves to get
# to get it
# get it in
# it in .
# in . there
# . there can
# there can also
# can also be
# also be a
# be a let
# a let if
# let if the
# if the server
# the server serves
# server serves the
# serves the ball
# the ball and
# ball and the
# and the receiver
# the receiver isnt
# receiver isnt prepared
# isnt prepared .
# prepared . if
# . if the
# if the server
# the server misses
# server misses his
# misses his or
# his or her
# or her first
# her first serve
# first serve and
# serve and gets
# and gets a
# gets a let
# a let on
# let on the
# on the second
# the second serve
# second serve then
# serve then they
# then they get
# they get one
# get one more
# one more try
# more try to
# try to get
# to get the
# get the serve
# the serve in
# serve in the
# in the box.experienced
# the box.experienced players
# box.experienced players strive
# players strive to
# strive to master
# to master the
# master the conventional
# the conventional overhand
# conventional overhand serve
# overhand serve to
# serve to maximize
# to maximize its
# maximize its power
# its power and
# power and placement
# and placement .
# placement . the
# . the server
# the server may
# server may employ
# may employ different
# employ different types
# different types of
# types of serve
# of serve including
# serve including flat
# including flat serve
# flat serve topspin
# serve topspin serve
# topspin serve slice
# serve slice serve
# slice serve and
# serve and kick
# and kick american
# kick american twist
# american twist serve
# twist serve .
# serve . a
# . a reverse
# a reverse type
# reverse type of
# type of spin
# of spin serve
# spin serve is
# serve is hit
# is hit in
# hit in a
# in a manner
# a manner that
# manner that spins
# that spins the
# spins the ball
# the ball opposite
# ball opposite the
# opposite the natural
# the natural spin
# natural spin of
# spin of the
# of the server
# the server the
# server the spin
# the spin direction
# spin direction depending
# direction depending upon
# depending upon right
# upon right or
# right or lefthandedness
# or lefthandedness .
# lefthandedness . if
# . if the
# if the ball
# the ball is
# ball is spinning
# is spinning counterclockwise
# spinning counterclockwise it
# counterclockwise it will
# it will curve
# will curve right
# curve right from
# right from the
# from the hitters
# the hitters point
# hitters point of
# point of view
# of view and
# view and curve
# and curve left
# curve left if
# left if spinning
# if spinning clockwise.some
# spinning clockwise.some servers
# clockwise.some servers are
# servers are content
# are content to
# content to use
# to use the
# use the serve
# the serve simply
# serve simply to
# simply to initiate
# to initiate the
# initiate the point
# the point however
# point however advanced
# however advanced players
# advanced players often
# players often try
# often try to
# try to hit
# to hit a
# hit a winning
# a winning shot
# winning shot with
# shot with their
# with their serve
# their serve .
# serve . a
# . a winning
# a winning serve
# winning serve that
# serve that is
# that is not
# is not touched
# not touched by
# touched by the
# by the opponent
# the opponent is
# opponent is called
# is called an
# called an ace.for
# an ace.for a
# ace.for a righthanded
# a righthanded player
# righthanded player the
# player the forehand
# the forehand is
# forehand is a
# is a stroke
# a stroke that
# stroke that begins
# that begins on
# begins on the
# on the right
# the right side
# right side of
# side of the
# of the body
# the body continues
# body continues across
# continues across the
# across the body
# the body as
# body as contact
# as contact is
# contact is made
# is made with
# made with the
# with the ball
# the ball and
# ball and ends
# and ends on
# ends on the
# on the left
# the left side
# left side of
# side of the
# of the body
# the body .
# body . there
# . there are
# there are various
# are various grips
# various grips for
# grips for executing
# for executing the
# executing the forehand
# the forehand and
# forehand and their
# and their popularity
# their popularity has
# popularity has fluctuated
# has fluctuated over
# fluctuated over the
# over the years
# the years .
# years . the
# . the most
# the most important
# most important ones
# important ones are
# ones are the
# are the continental
# the continental the
# continental the eastern
# the eastern the
# eastern the semiwestern
# the semiwestern and
# semiwestern and the
# and the western
# the western .
# western . for
# . for a
# for a number
# a number of
# number of years
# of years the
# years the small
# the small frail
# small frail s
# frail s player
# s player bill
# player bill johnston
# bill johnston was
# johnston was considered
# was considered by
# considered by many
# by many to
# many to have
# to have had
# have had the
# had the best
# the best forehand
# best forehand of
# forehand of all
# of all time
# all time a
# time a stroke
# a stroke that
# stroke that he
# that he hit
# he hit shoulderhigh
# hit shoulderhigh using
# shoulderhigh using a
# using a western
# a western grip
# western grip .
# grip . few
# . few top
# few top players
# top players used
# players used the
# used the western
# the western grip
# western grip after
# grip after the
# after the s
# the s but
# s but in
# but in the
# in the latter
# the latter part
# latter part of
# part of the
# of the th
# the th century
# th century as
# century as shotmaking
# as shotmaking techniques
# shotmaking techniques and
# techniques and equipment
# and equipment changed
# equipment changed radically
# changed radically the
# radically the western
# the western forehand
# western forehand made
# forehand made a
# made a strong
# a strong comeback
# strong comeback and
# comeback and is
# and is now
# is now used
# now used by
# used by many
# by many modern
# many modern players
# modern players .
# players . no
# . no matter
# no matter which
# matter which grip
# which grip is
# grip is used
# is used most
# used most forehands
# most forehands are
# forehands are generally
# are generally executed
# generally executed with
# executed with one
# with one hand
# one hand holding
# hand holding the
# holding the racket
# the racket but
# racket but there
# but there have
# there have been
# have been fine
# been fine players
# fine players with
# players with twohanded
# with twohanded forehands
# twohanded forehands .
# forehands . in
# . in the
# in the s
# the s and
# s and s
# and s the
# s the ecuadorianamerican
# the ecuadorianamerican player
# ecuadorianamerican player pancho
# player pancho segura
# pancho segura used
# segura used a
# used a twohanded
# a twohanded forehand
# twohanded forehand to
# forehand to achieve
# to achieve a
# achieve a devastating
# a devastating effect
# devastating effect against
# effect against larger
# against larger more
# larger more powerful
# more powerful players
# powerful players .
# players . players
# . players such
# players such as
# such as monica
# as monica seles
# monica seles or
# seles or frances
# or frances fabrice
# frances fabrice santoro
# fabrice santoro and
# santoro and marion
# and marion bartoli
# marion bartoli are
# bartoli are also
# are also notable
# also notable players
# notable players known
# players known for
# known for their
# for their twohanded
# their twohanded forehands.for
# twohanded forehands.for righthanded
# forehands.for righthanded players
# righthanded players the
# players the backhand
# the backhand is
# backhand is a
# is a stroke
# a stroke that
# stroke that begins
# that begins on
# begins on the
# on the left
# the left side
# left side of
# side of their
# of their body
# their body continues
# body continues across
# continues across their
# across their body
# their body as
# body as contact
# as contact is
# contact is made
# is made with
# made with the
# with the ball
# the ball and
# ball and ends
# and ends on
# ends on the
# on the right
# the right side
# right side of
# side of their
# of their body
# their body .
# body . it
# . it can
# it can be
# can be executed
# be executed with
# executed with either
# with either one
# either one hand
# one hand or
# hand or with
# or with both
# with both and
# both and is
# and is generally
# is generally considered
# generally considered more
# considered more difficult
# more difficult to
# difficult to master
# to master than
# master than the
# than the forehand
# the forehand .
# forehand . for
# . for most
# for most of
# most of the
# of the th
# the th century
# th century the
# century the backhand
# the backhand was
# backhand was performed
# was performed with
# performed with one
# with one hand
# one hand using
# hand using either
# using either an
# either an eastern
# an eastern or
# eastern or a
# or a continental
# a continental grip
# continental grip .
# grip . the
# . the first
# the first notable
# first notable players
# notable players to
# players to use
# to use two
# use two hands
# two hands were
# hands were the
# were the s
# the s australians
# s australians vivian
# australians vivian mcgrath
# vivian mcgrath and
# mcgrath and john
# and john bromwich
# john bromwich but
# bromwich but they
# but they were
# they were lonely
# were lonely exceptions
# lonely exceptions .
# exceptions . the
# . the twohanded
# the twohanded grip
# twohanded grip gained
# grip gained popularity
# gained popularity in
# popularity in the
# in the s
# the s as
# s as bjrn
# as bjrn borg
# bjrn borg chris
# borg chris evert
# chris evert jimmy
# evert jimmy connors
# jimmy connors and
# connors and later
# and later mats
# later mats wilander
# mats wilander and
# wilander and marat
# and marat safin
# marat safin used
# safin used it
# used it to
# it to great
# to great effect
# great effect and
# effect and it
# and it is
# it is now
# is now used
# now used by
# used by a
# by a large
# a large number
# large number of
# number of the
# of the worlds
# the worlds best
# worlds best players
# best players including
# players including novak
# including novak djokovic
# novak djokovic rafael
# djokovic rafael nadal
# rafael nadal and
# nadal and serena
# and serena williams.two
# serena williams.two hands
# williams.two hands give
# hands give the
# give the player
# the player more
# player more control
# more control while
# control while one
# while one hand
# one hand can
# hand can generate
# can generate a
# generate a slice
# a slice shot
# slice shot applying
# shot applying backspin
# applying backspin on
# backspin on the
# on the ball
# the ball to
# ball to produce
# to produce a
# produce a low
# a low trajectory
# low trajectory bounce
# trajectory bounce .
# bounce . reach
# . reach is
# reach is also
# is also limited
# also limited with
# limited with the
# with the twohanded
# the twohanded shot
# twohanded shot .
# shot . the
# . the player
# the player long
# player long considered
# long considered to
# considered to have
# to have had
# have had the
# had the best
# the best backhand
# best backhand of
# backhand of all
# of all time
# all time don
# time don budge
# don budge had
# budge had a
# had a powerful
# a powerful onehanded
# powerful onehanded stroke
# onehanded stroke in
# stroke in the
# in the s
# the s and
# s and s
# and s that
# s that imparted
# that imparted topspin
# imparted topspin onto
# topspin onto the
# onto the ball
# the ball .
# ball . ken
# . ken rosewall
# ken rosewall another
# rosewall another player
# another player noted
# player noted for
# noted for his
# for his onehanded
# his onehanded backhand
# onehanded backhand used
# backhand used a
# used a very
# a very accurate
# very accurate slice
# accurate slice backhand
# slice backhand through
# backhand through the
# through the s
# the s and
# s and s.
# and s. a
# s. a small
# a small number
# small number of
# number of players
# of players notably
# players notably monica
# notably monica seles
# monica seles use
# seles use two
# use two hands
# two hands on
# hands on both
# on both the
# both the backhand
# the backhand and
# backhand and forehand
# and forehand sides.a
# forehand sides.a volley
# sides.a volley is
# volley is a
# is a shot
# a shot returned
# shot returned to
# returned to the
# to the opponent
# the opponent in
# opponent in midair
# in midair before
# midair before the
# before the ball
# the ball bounces
# ball bounces generally
# bounces generally performed
# generally performed near
# performed near the
# near the net
# the net and
# net and is
# and is usually
# is usually made
# usually made with
# made with a
# with a stiffwristed
# a stiffwristed punching
# stiffwristed punching motion
# punching motion to
# motion to hit
# to hit the
# hit the ball
# the ball into
# ball into an
# into an open
# an open area
# open area of
# area of the
# of the opponents
# the opponents court
# opponents court .
# court . the
# . the half
# the half volley
# half volley is
# volley is made
# is made by
# made by hitting
# by hitting the
# hitting the ball
# the ball on
# ball on the
# on the rise
# the rise just
# rise just after
# just after it
# after it has
# it has bounced
# has bounced also
# bounced also generally
# also generally in
# generally in the
# in the vicinity
# the vicinity of
# vicinity of the
# of the net
# the net and
# net and played
# and played with
# played with the
# with the racket
# the racket close
# racket close to
# close to the
# to the ground
# the ground .
# ground . the
# . the swinging
# the swinging volley
# swinging volley is
# volley is hit
# is hit out
# hit out of
# out of the
# of the air
# the air as
# air as the
# as the player
# the player approaches
# player approaches the
# approaches the net
# the net .
# net . it
# . it is
# it is an
# is an offensive
# an offensive shot
# offensive shot used
# shot used to
# used to take
# to take preparation
# take preparation time
# preparation time away
# time away from
# away from the
# from the opponent
# the opponent as
# opponent as it
# as it returns
# it returns the
# returns the ball
# the ball into
# ball into the
# into the opponents
# the opponents court
# opponents court much
# court much faster
# much faster than
# faster than a
# than a standard
# a standard volley.from
# standard volley.from a
# volley.from a poor
# a poor defensive
# poor defensive position
# defensive position on
# position on the
# on the baseline
# the baseline the
# baseline the lob
# the lob can
# lob can be
# can be used
# be used as
# used as either
# as either an
# either an offensive
# an offensive or
# offensive or defensive
# or defensive weapon
# defensive weapon hitting
# weapon hitting the
# hitting the ball
# the ball high
# ball high and
# high and deep
# and deep into
# deep into the
# into the opponents
# the opponents court
# opponents court to
# court to either
# to either enable
# either enable the
# enable the lobber
# the lobber to
# lobber to get
# to get into
# get into better
# into better defensive
# better defensive position
# defensive position or
# position or to
# or to win
# to win the
# win the point
# the point outright
# point outright by
# outright by hitting
# by hitting it
# hitting it over
# it over the
# over the opponents
# the opponents head
# opponents head .
# head . if
# . if the
# if the lob
# the lob is
# lob is not
# is not hit
# not hit deeply
# hit deeply enough
# deeply enough into
# enough into the
# into the other
# the other court
# other court however
# court however an
# however an opponent
# an opponent near
# opponent near the
# near the net
# the net may
# net may then
# may then hit
# then hit an
# hit an overhead
# an overhead smash
# overhead smash a
# smash a hard
# a hard servelike
# hard servelike shot
# servelike shot to
# shot to try
# to try to
# try to end
# to end the
# end the point.a
# the point.a difficult
# point.a difficult shot
# difficult shot in
# shot in tennis
# in tennis is
# tennis is the
# is the return
# the return of
# return of an
# of an attempted
# an attempted lob
# attempted lob over
# lob over the
# over the backhand
# the backhand side
# backhand side of
# side of a
# of a player
# a player .
# player . when
# . when the
# when the contact
# the contact point
# contact point is
# point is higher
# is higher than
# higher than the
# than the reach
# the reach of
# reach of a
# of a twohanded
# a twohanded backhand
# twohanded backhand most
# backhand most players
# most players will
# players will try
# will try to
# try to execute
# to execute a
# execute a high
# a high slice
# high slice under
# slice under the
# under the ball
# the ball or
# ball or sideways
# or sideways .
# sideways . fewer
# . fewer players
# fewer players attempt
# players attempt the
# attempt the backhand
# the backhand skyhook
# backhand skyhook or
# skyhook or smash
# or smash .
# smash . rarely
# . rarely a
# rarely a player
# a player will
# player will go
# will go for
# go for a
# for a high
# a high topspin
# high topspin backhand
# topspin backhand while
# backhand while themselves
# while themselves in
# themselves in the
# in the air
# the air .
# air . a
# . a successful
# a successful execution
# successful execution of
# execution of any
# of any of
# any of these
# of these alternatives
# these alternatives requires
# alternatives requires balance
# requires balance and
# balance and timing
# and timing with
# timing with less
# with less margin
# less margin of
# margin of error
# of error than
# error than the
# than the lower
# the lower contact
# lower contact point
# contact point backhands
# point backhands since
# backhands since this
# since this shot
# this shot is
# shot is a
# is a break
# a break in
# break in the
# in the regular
# the regular pattern
# regular pattern of
# pattern of play.if
# of play.if their
# play.if their opponent
# their opponent is
# opponent is deep
# is deep in
# deep in their
# in their court
# their court a
# court a player
# a player may
# player may suddenly
# may suddenly employ
# suddenly employ an
# employ an unexpected
# an unexpected drop
# unexpected drop shot
# drop shot by
# shot by softly
# by softly tapping
# softly tapping the
# tapping the ball
# the ball just
# ball just over
# just over the
# over the net
# the net so
# net so that
# so that the
# that the opponent
# the opponent is
# opponent is unable
# is unable to
# unable to run
# to run in
# run in fast
# in fast enough
# fast enough to
# enough to retrieve
# to retrieve it
# retrieve it .
# it . advanced
# . advanced players
# advanced players will
# players will often
# will often apply
# often apply back
# apply back spin
# back spin to
# spin to a
# to a drop
# a drop shot
# drop shot causing
# shot causing the
# causing the ball
# the ball to
# ball to skid
# to skid upon
# skid upon landing
# upon landing and
# landing and bounce
# and bounce sideways
# bounce sideways with
# sideways with less
# with less forward
# less forward momentum
# forward momentum toward
# momentum toward their
# toward their opponent
# their opponent or
# opponent or even
# or even backwards
# even backwards towards
# backwards towards the
# towards the net
# the net thus
# net thus making
# thus making it
# making it even
# it even more
# even more difficult
# more difficult to
# difficult to return.tournaments
# to return.tournaments are
# return.tournaments are often
# are often organized
# often organized by
# organized by gender
# by gender and
# gender and number
# and number of
# number of players
# of players .
# players . common
# . common tournament
# common tournament configurations
# tournament configurations include
# configurations include mens
# include mens singles
# mens singles womens
# singles womens singles
# womens singles and
# singles and doubles
# and doubles where
# doubles where two
# where two players
# two players play
# players play on
# play on each
# on each side
# each side of
# side of the
# of the net
# the net .
# net . tournaments
# . tournaments may
# tournaments may be
# may be organized
# be organized for
# organized for specific
# for specific age
# specific age groups
# age groups with
# groups with upper
# with upper age
# upper age limits
# age limits for
# limits for youth
# for youth and
# youth and lower
# and lower age
# lower age limits
# age limits for
# limits for senior
# for senior players
# senior players .
# players . example
# . example of
# example of this
# of this include
# this include the
# include the orange
# the orange bowl
# orange bowl and
# bowl and les
# and les petits
# les petits as
# petits as junior
# as junior tournaments
# junior tournaments .
# tournaments . there
# . there are
# there are also
# are also tournaments
# also tournaments for
# tournaments for players
# for players with
# players with disabilities
# with disabilities such
# disabilities such as
# such as wheelchair
# as wheelchair tennis
# wheelchair tennis and
# tennis and deaf
# and deaf tennis
# deaf tennis .
# tennis . in
# . in the
# in the four
# the four grand
# four grand slam
# grand slam tournaments
# slam tournaments the
# tournaments the singles
# the singles draws
# singles draws are
# draws are limited
# are limited to
# limited to players
# to players for
# players for each
# for each gender.most
# each gender.most large
# gender.most large tournaments
# large tournaments seed
# tournaments seed players
# seed players but
# players but players
# but players may
# players may also
# may also be
# also be matched
# be matched by
# matched by their
# by their skill
# their skill level
# skill level .
# level . according
# . according to
# according to how
# to how well
# how well a
# well a person
# a person does
# person does in
# does in sanctioned
# in sanctioned play
# sanctioned play a
# play a player
# a player is
# player is given
# is given a
# given a rating
# a rating that
# rating that is
# that is adjusted
# is adjusted periodically
# adjusted periodically to
# periodically to maintain
# to maintain competitive
# maintain competitive matches
# competitive matches .
# matches . for
# . for example
# for example the
# example the united
# the united states
# united states tennis
# states tennis association
# tennis association administers
# association administers the
# administers the national
# the national tennis
# national tennis rating
# tennis rating program
# rating program ntrp
# program ntrp which
# ntrp which rates
# which rates players
# rates players between
# players between .
# between . and
# . and .
# and . in
# . in point
# in point increments
# point increments .
# increments . average
# . average club
# average club players
# club players under
# players under this
# under this system
# this system would
# system would rate
# would rate ..
# rate .. while
# .. while world
# while world class
# world class players
# class players would
# players would be
# would be .
# be . on
# . on this
# on this scale.the
# this scale.the four
# scale.the four grand
# four grand slam
# grand slam tournaments
# slam tournaments are
# tournaments are considered
# are considered to
# considered to be
# to be the
# be the most
# the most prestigious
# most prestigious tennis
# prestigious tennis events
# tennis events in
# events in the
# in the world
# the world .
# world . they
# . they are
# they are held
# are held annually
# held annually and
# annually and comprise
# and comprise in
# comprise in chronological
# in chronological order
# chronological order the
# order the australian
# the australian open
# australian open the
# open the french
# the french open
# french open wimbledon
# open wimbledon and
# wimbledon and the
# and the us
# the us open
# us open .
# open . apart
# . apart from
# apart from the
# from the olympic
# the olympic games
# olympic games davis
# games davis cup
# davis cup fed
# cup fed cup
# fed cup and
# cup and hopman
# and hopman cup
# hopman cup they
# cup they are
# they are the
# are the only
# the only tournaments
# only tournaments regulated
# tournaments regulated by
# regulated by the
# by the international
# the international tennis
# international tennis federation
# tennis federation itf
# federation itf .
# itf . the
# . the itfs
# the itfs national
# itfs national associations
# national associations tennis
# associations tennis australia
# tennis australia australian
# australia australian open
# australian open the
# open the fdration
# the fdration franaise
# fdration franaise de
# franaise de tennis
# de tennis french
# tennis french open
# french open the
# open the lawn
# the lawn tennis
# lawn tennis association
# tennis association wimbledon
# association wimbledon and
# wimbledon and the
# and the united
# the united states
# united states tennis
# states tennis association
# tennis association us
# association us open
# us open are
# open are delegated
# are delegated the
# delegated the responsibility
# the responsibility to
# responsibility to organize
# to organize these
# organize these events.aside
# these events.aside from
# events.aside from the
# from the historical
# the historical significance
# historical significance of
# significance of these
# of these events
# these events they
# events they also
# they also carry
# also carry larger
# carry larger prize
# larger prize funds
# prize funds than
# funds than any
# than any other
# any other tour
# other tour event
# tour event and
# event and are
# and are worth
# are worth double
# worth double the
# double the number
# the number of
# number of ranking
# of ranking points
# ranking points to
# points to the
# to the champion
# the champion than
# champion than in
# than in the
# in the next
# the next echelon
# next echelon of
# echelon of tournaments
# of tournaments the
# tournaments the atp
# the atp masters
# atp masters men
# masters men and
# men and premier
# and premier events
# premier events women
# events women .
# women . another
# . another distinguishing
# another distinguishing feature
# distinguishing feature is
# feature is the
# is the number
# the number of
# number of players
# of players in
# players in the
# in the singles
# the singles draw
# singles draw .
# draw . there
# . there are
# there are more
# are more than
# more than any
# than any other
# any other professional
# other professional tennis
# professional tennis tournament
# tennis tournament .
# tournament . this
# . this draw
# this draw is
# draw is composed
# is composed of
# composed of seeded
# of seeded players
# seeded players other
# players other players
# other players ranked
# players ranked in
# ranked in the
# in the worlds
# the worlds top
# worlds top qualifiers
# top qualifiers and
# qualifiers and players
# and players who
# players who receive
# who receive invitations
# receive invitations through
# invitations through wild
# through wild cards
# wild cards .
# cards . grand
# . grand slam
# grand slam mens
# slam mens tournaments
# mens tournaments have
# tournaments have bestoffive
# have bestoffive set
# bestoffive set matches
# set matches while
# matches while the
# while the women
# the women play
# women play bestofthree
# play bestofthree .
# bestofthree . grand
# . grand slam
# grand slam tournaments
# slam tournaments are
# tournaments are among
# are among the
# among the small
# the small number
# small number of
# number of events
# of events that
# events that last
# that last two
# last two weeks
# two weeks the
# weeks the others
# the others being
# others being the
# being the indian
# the indian wells
# indian wells masters
# wells masters and
# masters and the
# and the miami
# the miami masters.currently
# miami masters.currently the
# masters.currently the grand
# the grand slam
# grand slam tournaments
# slam tournaments are
# tournaments are the
# are the only
# the only tour
# only tour events
# tour events that
# events that have
# that have mixed
# have mixed doubles
# mixed doubles contests
# doubles contests .
# contests . grand
# . grand slam
# grand slam tournaments
# slam tournaments are
# tournaments are held
# are held in
# held in conjunction
# in conjunction with
# conjunction with wheelchair
# with wheelchair tennis
# wheelchair tennis tournaments
# tennis tournaments and
# tournaments and junior
# and junior tennis
# junior tennis competitions
# tennis competitions .
# competitions . these
# . these tournaments
# these tournaments also
# tournaments also contain
# also contain their
# contain their own
# their own idiosyncrasies
# own idiosyncrasies .
# idiosyncrasies . for
# . for example
# for example players
# example players at
# players at wimbledon
# at wimbledon are
# wimbledon are required
# are required to
# required to wear
# to wear predominantly
# wear predominantly white
# predominantly white .
# white . andre
# . andre agassi
# andre agassi chose
# agassi chose to
# chose to skip
# to skip wimbledon
# skip wimbledon from
# wimbledon from through
# from through citing
# through citing the
# citing the events
# the events traditionalism
# events traditionalism particularly
# traditionalism particularly its
# particularly its predominantly
# its predominantly white
# predominantly white dress
# white dress code
# dress code .
# code . wimbledon
# . wimbledon has
# wimbledon has its
# has its own
# its own particular
# own particular methods
# particular methods for
# methods for disseminating
# for disseminating tickets
# disseminating tickets often
# tickets often leading
# often leading tennis
# leading tennis fans
# tennis fans to
# fans to follow
# to follow complex
# follow complex procedures
# complex procedures to
# procedures to obtain
# to obtain tickets.the
# obtain tickets.the atp
# tickets.the atp masters
# atp masters is
# masters is a
# is a group
# a group of
# group of nine
# of nine tournaments
# nine tournaments that
# tournaments that form
# that form the
# form the secondhighest
# the secondhighest echelon
# secondhighest echelon in
# echelon in mens
# in mens tennis
# mens tennis .
# tennis . each
# . each event
# each event is
# event is held
# is held annually
# held annually and
# annually and a
# and a win
# a win at
# win at one
# at one of
# one of these
# of these events
# these events is
# events is worth
# is worth ranking
# worth ranking points
# ranking points .
# points . when
# . when the
# when the atp
# the atp led
# atp led by
# led by hamilton
# by hamilton jordan
# hamilton jordan began
# jordan began running
# began running the
# running the mens
# the mens tour
# mens tour in
# tour in the
# in the directors
# the directors designated
# directors designated the
# designated the top
# the top nine
# top nine tournaments
# nine tournaments outside
# tournaments outside of
# outside of the
# of the grand
# the grand slam
# grand slam events
# slam events as
# events as super
# as super events
# super events .
# events . in
# . in this
# in this became
# this became the
# became the tennis
# the tennis masters
# tennis masters series
# masters series and
# series and in
# and in the
# in the atp
# the atp masters
# atp masters series
# masters series .
# series . in
# . in november
# in november at
# november at the
# at the end
# the end of
# end of the
# of the tennis
# the tennis year
# tennis year the
# year the worlds
# the worlds top
# worlds top eight
# top eight players
# eight players compete
# players compete in
# compete in the
# in the atp
# the atp finals
# atp finals a
# finals a tournament
# a tournament with
# tournament with a
# with a rotating
# a rotating locale
# rotating locale .
# locale . it
# . it is
# it is currently
# is currently held
# currently held in
# held in london.in
# in london.in august
# london.in august the
# august the atp
# the atp announced
# atp announced major
# announced major changes
# major changes to
# changes to the
# to the tour
# the tour that
# tour that were
# that were introduced
# were introduced in
# introduced in .
# in . the
# . the masters
# the masters series
# masters series was
# series was renamed
# was renamed to
# renamed to the
# to the atp
# the atp masters
# atp masters the
# masters the addition
# the addition of
# addition of the
# of the number
# the number referring
# number referring to
# referring to the
# to the number
# the number of
# number of ranking
# of ranking points
# ranking points earned
# points earned by
# earned by the
# by the winner
# the winner of
# winner of each
# of each tournament
# each tournament .
# tournament . contrary
# . contrary to
# contrary to earlier
# to earlier plans
# earlier plans the
# plans the number
# the number of
# number of tournaments
# of tournaments was
# tournaments was not
# was not reduced
# not reduced from
# reduced from nine
# from nine to
# nine to eight
# to eight and
# eight and the
# and the montecarlo
# the montecarlo masters
# montecarlo masters remains
# masters remains part
# remains part of
# part of the
# of the series
# the series although
# series although unlike
# although unlike the
# unlike the other
# the other events
# other events it
# events it does
# it does not
# does not have
# not have a
# have a mandatory
# a mandatory player
# mandatory player commitment
# player commitment .
# commitment . the
# . the hamburg
# the hamburg masters
# hamburg masters has
# masters has been
# has been downgraded
# been downgraded to
# downgraded to a
# to a point
# a point event
# point event .
# event . the
# . the madrid
# the madrid masters
# madrid masters moved
# masters moved to
# moved to may
# to may and
# may and onto
# and onto clay
# onto clay courts
# clay courts and
# courts and a
# and a new
# a new tournament
# new tournament in
# tournament in shanghai
# in shanghai took
# shanghai took over
# took over madrids
# over madrids former
# madrids former indoor
# former indoor october
# indoor october slot
# october slot .
# slot . as
# . as of
# as of six
# of six of
# six of the
# of the nine
# the nine level
# nine level tournaments
# level tournaments are
# tournaments are combined
# are combined atp
# combined atp and
# atp and wta
# and wta events.the
# wta events.the third
# events.the third and
# third and fourth
# and fourth tier
# fourth tier of
# tier of mens
# of mens tennis
# mens tennis tournaments
# tennis tournaments are
# tournaments are formed
# are formed by
# formed by the
# by the atp
# the atp series
# atp series consisting
# series consisting of
# consisting of tournaments
# of tournaments and
# tournaments and the
# and the atp
# the atp series
# atp series with
# series with tournaments
# with tournaments .
# tournaments . like
# . like the
# like the atp
# the atp masters
# atp masters these
# masters these events
# these events offer
# events offer various
# offer various amounts
# various amounts of
# amounts of prize
# of prize money
# prize money and
# money and the
# and the numbers
# the numbers refer
# numbers refer to
# refer to the
# to the number
# the number of
# number of ranking
# of ranking points
# ranking points earned
# points earned by
# earned by the
# by the winner
# the winner of
# winner of a
# of a tournament
# a tournament .
# tournament . the
# . the dubai
# the dubai tennis
# dubai tennis championships
# tennis championships offer
# championships offer the
# offer the largest
# the largest financial
# largest financial incentive
# financial incentive to
# incentive to players
# to players with
# players with total
# with total prize
# total prize money
# prize money of
# money of us
# of us .
# us . these
# . these series
# these series have
# series have various
# have various draws
# various draws of
# draws of and
# of and for
# and for singles
# for singles and
# singles and and
# and and for
# and for doubles
# for doubles .
# doubles . it
# . it is
# it is mandatory
# is mandatory for
# mandatory for leading
# for leading players
# leading players to
# players to enter
# to enter at
# enter at least
# at least four
# least four events
# four events including
# events including at
# including at least
# at least one
# least one after
# one after the
# after the us
# the us open.the
# us open.the challenger
# open.the challenger tour
# challenger tour for
# tour for men
# for men is
# men is the
# is the lowest
# the lowest level
# lowest level of
# level of tournament
# of tournament administered
# tournament administered by
# administered by the
# by the atp
# the atp .
# atp . it
# . it is
# it is composed
# is composed of
# composed of about
# of about events
# about events and
# events and as
# and as a
# as a result
# a result features
# result features a
# features a more
# a more diverse
# more diverse range
# diverse range of
# range of countries
# of countries hosting
# countries hosting events
# hosting events .
# events . the
# . the majority
# the majority of
# majority of players
# of players use
# players use the
# use the challenger
# the challenger series
# challenger series at
# series at the
# at the beginning
# the beginning of
# beginning of their
# of their career
# their career to
# career to work
# to work their
# work their way
# their way up
# way up the
# up the rankings
# the rankings .
# rankings . andre
# . andre agassi
# andre agassi between
# agassi between winning
# between winning grand
# winning grand slam
# grand slam tournaments
# slam tournaments plummeted
# tournaments plummeted to
# plummeted to world
# to world no
# world no .
# no . and
# . and used
# and used challenger
# used challenger series
# challenger series events
# series events for
# events for match
# for match experience
# match experience and
# experience and to
# and to progress
# to progress back
# progress back up
# back up the
# up the rankings
# the rankings .
# rankings . the
# . the challenger
# the challenger series
# challenger series offers
# series offers prize
# offers prize funds
# prize funds of
# funds of between
# of between us
# between us and
# us and us.below
# and us.below the
# us.below the challenger
# the challenger tour
# challenger tour are
# tour are the
# are the futures
# the futures tournaments
# futures tournaments events
# tournaments events on
# events on the
# on the itf
# the itf mens
# itf mens circuit
# mens circuit .
# circuit . these
# . these tournaments
# these tournaments also
# tournaments also contribute
# also contribute towards
# contribute towards a
# towards a players
# a players atp
# players atp rankings
# atp rankings points
# rankings points .
# points . futures
# . futures tournaments
# futures tournaments offer
# tournaments offer prize
# offer prize funds
# prize funds of
# funds of between
# of between us
# between us and
# us and us
# and us .
# us . approximately
# . approximately futures
# approximately futures tournaments
# futures tournaments are
# tournaments are played
# are played each
# played each year.in
# each year.in the
# year.in the wta
# the wta rebranded
# wta rebranded resembling
# rebranded resembling the
# resembling the mens
# the mens tournament
# mens tournament series
# tournament series and
# series and also
# and also providing
# also providing extra
# providing extra simplicity
# extra simplicity for
# simplicity for fans
# for fans and
# fans and consumers
# and consumers .
# consumers . the
# . the numbers
# the numbers do
# numbers do not
# do not indicate
# not indicate ranking
# indicate ranking points
# ranking points or
# points or prize
# or prize money
# prize money but
# money but is
# but is a
# is a system
# a system to
# system to help
# to help define
# help define different
# define different levels
# different levels of
# levels of womens
# of womens tennis.the
# womens tennis.the wta
# tennis.the wta tournaments
# wta tournaments formerly
# tournaments formerly the
# formerly the premier
# the premier mandatory
# premier mandatory and
# mandatory and premier
# and premier tournaments
# premier tournaments are
# tournaments are a
# are a series
# a series of
# series of seven
# of seven tournaments
# seven tournaments that
# tournaments that are
# that are part
# are part of
# part of the
# of the secondhighest
# the secondhighest tier
# secondhighest tier in
# tier in womens
# in womens tennis.the
# womens tennis.the third
# tennis.the third and
# third and fourth
# and fourth tier
# fourth tier of
# tier of womens
# of womens tennis
# womens tennis tournaments
# tennis tournaments are
# tournaments are formed
# are formed from
# formed from the
# from the wta
# the wta series
# wta series formerly
# series formerly premier
# formerly premier with
# premier with fifteen
# with fifteen tournaments
# fifteen tournaments and
# tournaments and the
# and the wta
# the wta series
# wta series formerly
# series formerly international
# formerly international consisting
# international consisting of
# consisting of thirty
# of thirty tournaments.the
# thirty tournaments.the wta
# tournaments.the wta series
# wta series formerly
# series formerly k
# formerly k series
# k series is
# series is the
# is the lowest
# the lowest tier
# lowest tier of
# tier of womens
# of womens tennis
# womens tennis with
# tennis with fourteen
# with fourteen tournaments.professional
# fourteen tournaments.professional tennis
# tournaments.professional tennis players
# tennis players enjoy
# players enjoy the
# enjoy the same
# the same relative
# same relative perks
# relative perks as
# perks as most
# as most top
# most top sports
# top sports personalities
# sports personalities clothing
# personalities clothing equipment
# clothing equipment and
# equipment and endorsements
# and endorsements .
# endorsements . like
# . like players
# like players of
# players of other
# of other individual
# other individual sports
# individual sports such
# sports such as
# such as golf
# as golf they
# golf they are
# they are not
# are not salaried
# not salaried but
# salaried but must
# but must play
# must play and
# play and finish
# and finish highly
# finish highly in
# highly in tournaments
# in tournaments to
# tournaments to obtain
# to obtain prize
# obtain prize money.in
# prize money.in recent
# money.in recent years
# recent years professional
# years professional tennis
# professional tennis players
# tennis players have
# players have been
# have been mocked
# been mocked by
# mocked by tabloids
# by tabloids and
# tabloids and fans
# and fans for
# fans for the
# for the involuntary
# the involuntary or
# involuntary or deliberate
# or deliberate noise
# deliberate noise caused
# noise caused by
# caused by players
# by players grunting
# players grunting .
# grunting . this
# . this controversy
# this controversy has
# controversy has spurred
# has spurred the
# spurred the grand
# the grand slam
# grand slam committee
# slam committee the
# committee the international
# the international tennis
# international tennis association
# tennis association and
# association and the
# and the womens
# the womens tennis
# womens tennis association
# tennis association to
# association to teach
# to teach players
# teach players techniques
# players techniques to
# techniques to avoid
# to avoid grunting.while
# avoid grunting.while players
# grunting.while players are
# players are gradually
# are gradually less
# gradually less competitive
# less competitive in
# competitive in singles
# in singles by
# singles by their
# by their late
# their late s
# late s and
# s and early
# and early s
# early s they
# s they can
# they can still
# can still continue
# still continue competitively
# continue competitively in
# competitively in doubles
# in doubles as
# doubles as instanced
# as instanced by
# instanced by martina
# by martina navratilova
# martina navratilova and
# navratilova and john
# and john mcenroe
# john mcenroe who
# mcenroe who won
# who won doubles
# won doubles titles
# doubles titles in
# titles in their
# in their s.in
# their s.in the
# s.in the open
# the open era
# open era several
# era several female
# several female players
# female players such
# players such as
# such as martina
# as martina navratilova
# martina navratilova margaret
# navratilova margaret court
# margaret court martina
# court martina hingis
# martina hingis serena
# hingis serena williams
# serena williams and
# williams and venus
# and venus williams
# venus williams the
# williams the latter
# the latter two
# latter two sisters
# two sisters playing
# sisters playing together
# playing together have
# together have been
# have been prolific
# been prolific at
# prolific at both
# at both singles
# both singles and
# singles and doubles
# and doubles events
# doubles events throughout
# events throughout their
# throughout their careers
# their careers .
# careers . john
# . john mcenroe
# john mcenroe is
# mcenroe is one
# is one of
# one of the
# of the very
# the very few
# very few professional
# few professional male
# professional male players
# male players to
# players to be
# to be top
# be top ranked
# top ranked in
# ranked in both
# in both singles
# both singles and
# singles and doubles
# and doubles at
# doubles at the
# at the same
# the same time
# same time and
# time and yevgeny
# and yevgeny kafelnikov
# yevgeny kafelnikov is
# kafelnikov is the
# is the most
# the most recent
# most recent male
# recent male player
# male player to
# player to win
# to win multiple
# win multiple grand
# multiple grand slams
# grand slams in
# slams in both
# in both singles
# both singles and
# singles and doubles
# and doubles during
# doubles during the
# during the same
# the same period
# same period of
# period of his
# of his career.in
# his career.in terms
# career.in terms of
# terms of public
# of public attention
# public attention and
# attention and earnings
# and earnings see
# earnings see below
# see below singles
# below singles champions
# singles champions have
# champions have far
# have far surpassed
# far surpassed their
# surpassed their doubles
# their doubles counterparts
# doubles counterparts .
# counterparts . the
# . the open
# the open era
# open era particularly
# era particularly the
# particularly the mens
# the mens side
# mens side has
# side has seen
# has seen many
# seen many topranked
# many topranked singles
# topranked singles players
# singles players that
# players that only
# that only sparingly
# only sparingly compete
# sparingly compete in
# compete in doubles
# in doubles while
# doubles while having
# while having doubles
# having doubles specialists
# doubles specialists who
# specialists who are
# who are typically
# are typically being
# typically being eliminated
# being eliminated early
# eliminated early in
# early in the
# in the singles
# the singles draw
# singles draw but
# draw but do
# but do well
# do well in
# well in the
# in the doubles
# the doubles portion
# doubles portion of
# portion of a
# of a tournament
# a tournament .
# tournament . notable
# . notable doubles
# notable doubles pairings
# doubles pairings include
# pairings include the
# include the woodies
# the woodies todd
# woodies todd woodbridge
# todd woodbridge and
# woodbridge and mark
# and mark woodforde
# mark woodforde and
# woodforde and the
# and the bryan
# the bryan brothers
# bryan brothers identical
# brothers identical twin
# identical twin brothers
# twin brothers robert
# brothers robert charles
# robert charles bob
# charles bob bryan
# bob bryan and
# bryan and michael
# and michael carl
# michael carl mike
# carl mike bryan
# mike bryan .
# bryan . woodbridge
# . woodbridge has
# woodbridge has disliked
# ...
# panel of experts
# of experts assembled
# experts assembled by
# assembled by the
# by the associated
# the associated press
# associated press .
# press . tennis
# . tennis writer
# tennis writer steve
# writer steve flink
# steve flink in
# flink in his
# in his book
# his book the
# book the greatest
# the greatest tennis
# greatest tennis matches
# tennis matches of
# matches of the
# of the twentieth
# the twentieth century
# twentieth century named
# century named her
# named her as
# her as the
# as the best
# the best female
# best female player
# female player of
# player of the
# of the th
# the th century
# th century directly
# century directly followed
# directly followed by
# followed by martina
# by martina navratilova.tennis
# martina navratilova.tennis magazine
# navratilova.tennis magazine selected
# magazine selected martina
# selected martina navratilova
# martina navratilova as
# navratilova as the
# as the greatest
# the greatest female
# greatest female tennis
# female tennis player
# tennis player for
# player for the
# for the years
# the years through
# years through .
# through . tennis
# . tennis historian
# tennis historian and
# historian and journalist
# and journalist bud
# journalist bud collins
# bud collins has
# collins has called
# has called navratilova
# called navratilova arguably
# navratilova arguably the
# arguably the greatest
# the greatest player
# greatest player of
# player of all
# of all time
# all time .
# time . billie
# . billie jean
# billie jean king
# jean king said
# king said about
# said about navratilova
# about navratilova in
# navratilova in shes
# in shes the
# shes the greatest
# the greatest singles
# greatest singles doubles
# singles doubles and
# doubles and mixed
# and mixed doubles
# mixed doubles player
# doubles player whos
# player whos ever
# whos ever lived.in
# ever lived.in a
# lived.in a tennis.com
# a tennis.com panel
# tennis.com panel selected
# panel selected serena
# selected serena williams
# serena williams as
# williams as the
# as the greatest
# the greatest female
# greatest female tennis
# female tennis player
# tennis player in
# player in the
# in the open
# the open era
# open era .
# era . in
# . in may
# in may the
# may the tennis
# the tennis channel
# tennis channel ranked
# channel ranked williams
# ranked williams as
# williams as the
# as the greatest
# the greatest female
# greatest female tennis
# female tennis player
# tennis player of
# player of all
# of all time.in
# all time.in most
# time.in most professional
# most professional play
# professional play and
# play and some
# and some amateur
# some amateur competition
# amateur competition there
# competition there is
# there is an
# is an officiating
# an officiating head
# officiating head judge
# head judge or
# judge or chair
# or chair umpire
# chair umpire usually
# umpire usually referred
# usually referred to
# referred to simply
# to simply as
# simply as the
# as the umpire
# the umpire who
# umpire who sits
# who sits in
# sits in a
# in a raised
# a raised chair
# raised chair to
# chair to one
# to one side
# one side of
# side of the
# of the court
# the court .
# court . the
# . the umpire
# the umpire has
# umpire has absolute
# has absolute authority
# absolute authority to
# authority to make
# to make factual
# make factual determinations
# factual determinations .
# determinations . the
# . the umpire
# the umpire may
# umpire may be
# may be assisted
# be assisted by
# assisted by line
# by line judges
# line judges who
# judges who determine
# who determine whether
# determine whether the
# whether the ball
# the ball has
# ball has landed
# has landed within
# landed within the
# within the required
# the required part
# required part of
# part of the
# of the court
# the court and
# court and who
# and who also
# who also call
# also call foot
# call foot faults
# foot faults .
# faults . there
# . there also
# there also may
# also may be
# may be a
# be a net
# a net judge
# net judge who
# judge who determines
# who determines whether
# determines whether the
# whether the ball
# the ball has
# ball has touched
# has touched the
# touched the net
# the net during
# net during service
# during service .
# service . the
# . the umpire
# the umpire has
# umpire has the
# has the right
# the right to
# right to overrule
# to overrule a
# overrule a line
# a line judge
# line judge or
# judge or a
# or a net
# a net judge
# net judge if
# judge if the
# if the umpire
# the umpire is
# umpire is sure
# is sure that
# sure that a
# that a clear
# a clear mistake
# clear mistake has
# mistake has been
# has been made.in
# been made.in past
# made.in past tournaments
# past tournaments line
# tournaments line judges
# line judges tasked
# judges tasked with
# tasked with calling
# with calling the
# calling the serve
# the serve were
# serve were sometimes
# were sometimes assisted
# sometimes assisted by
# assisted by electronic
# by electronic sensors
# electronic sensors that
# sensors that beeped
# that beeped to
# beeped to indicate
# to indicate an
# indicate an outofbounds
# an outofbounds serve
# outofbounds serve one
# serve one such
# one such system
# such system was
# system was called
# was called cyclops
# called cyclops .
# cyclops . cyclops
# . cyclops has
# cyclops has since
# has since largely
# since largely been
# largely been replaced
# been replaced by
# replaced by the
# by the hawkeye
# the hawkeye system
# hawkeye system .
# system . in
# . in professional
# in professional tournaments
# professional tournaments using
# tournaments using this
# using this system
# this system players
# system players are
# players are allowed
# are allowed three
# allowed three unsuccessful
# three unsuccessful appeals
# unsuccessful appeals per
# appeals per set
# per set plus
# set plus one
# plus one additional
# one additional appeal
# additional appeal in
# appeal in the
# in the tiebreak
# the tiebreak to
# tiebreak to challenge
# to challenge close
# challenge close line
# close line calls
# line calls by
# calls by means
# by means of
# means of an
# of an electronic
# an electronic review
# electronic review .
# review . the
# . the us
# the us open
# us open miami
# open miami masters
# miami masters us
# masters us open
# us open series
# open series and
# series and world
# and world team
# world team tennis
# team tennis started
# tennis started using
# started using this
# using this challenge
# this challenge system
# challenge system in
# system in and
# in and the
# and the australian
# the australian open
# australian open and
# open and wimbledon
# and wimbledon introduced
# wimbledon introduced the
# introduced the system
# the system in
# system in .
# in . in
# . in claycourt
# in claycourt matches
# claycourt matches such
# matches such as
# such as at
# as at the
# at the french
# the french open
# french open a
# open a call
# a call may
# call may be
# may be questioned
# be questioned by
# questioned by reference
# by reference to
# reference to the
# to the mark
# the mark left
# mark left by
# left by the
# by the balls
# the balls impact
# balls impact on
# impact on the
# on the court
# the court surface.the
# court surface.the referee
# surface.the referee who
# referee who is
# who is usually
# is usually located
# usually located off
# located off the
# off the court
# the court is
# court is the
# is the final
# the final authority
# final authority about
# authority about tennis
# about tennis rules
# tennis rules .
# rules . when
# . when called
# when called to
# called to the
# to the court
# the court by
# court by a
# by a player
# a player or
# player or team
# or team captain
# team captain the
# captain the referee
# the referee may
# referee may overrule
# may overrule the
# overrule the umpires
# the umpires decision
# umpires decision if
# decision if the
# if the tennis
# the tennis rules
# tennis rules were
# rules were violated
# were violated question
# violated question of
# question of law
# of law but
# law but may
# but may not
# may not change
# not change the
# change the umpires
# the umpires decision
# umpires decision on
# decision on a
# on a question
# a question of
# question of fact
# of fact .
# fact . if
# . if however
# if however the
# however the referee
# the referee is
# referee is on
# is on the
# on the court
# the court during
# court during play
# during play the
# play the referee
# the referee may
# referee may overrule
# may overrule the
# overrule the umpires
# the umpires decision
# umpires decision .
# decision . this
# . this would
# this would only
# would only happen
# only happen in
# happen in davis
# in davis cup
# davis cup or
# cup or fed
# or fed cup
# fed cup matches
# cup matches not
# matches not at
# not at the
# at the world
# the world group
# world group level
# group level when
# level when a
# when a chair
# a chair umpire
# chair umpire from
# umpire from a
# from a nonneutral
# a nonneutral country
# nonneutral country is
# country is in
# is in the
# in the chair.in
# the chair.in tennis
# chair.in tennis a
# tennis a junior
# a junior is
# junior is a
# is a player
# a player under
# player under who
# under who is
# who is still
# is still legally
# still legally protected
# legally protected by
# protected by a
# by a parent
# a parent or
# parent or guardian
# or guardian .
# guardian . players
# . players on
# players on the
# on the main
# the main adult
# main adult tour
# adult tour who
# tour who are
# who are under
# are under must
# under must have
# must have documents
# have documents signed
# documents signed by
# signed by a
# by a parent
# a parent or
# parent or guardian
# or guardian .
# guardian . these
# . these players
# these players however
# players however are
# however are still
# are still eligible
# still eligible to
# eligible to play
# to play in
# play in junior
# in junior tournaments.the
# junior tournaments.the international
# tournaments.the international tennis
# international tennis federation
# tennis federation itf
# federation itf conducts
# itf conducts a
# conducts a junior
# a junior tour
# junior tour that
# tour that allows
# that allows juniors
# allows juniors to
# juniors to establish
# to establish a
# establish a world
# a world ranking
# world ranking and
# ranking and an
# and an association
# an association of
# association of tennis
# of tennis professionals
# tennis professionals atp
# professionals atp or
# atp or womens
# or womens tennis
# womens tennis association
# tennis association wta
# association wta ranking
# wta ranking .
# ranking . most
# . most juniors
# most juniors who
# juniors who enter
# who enter the
# enter the international
# the international circuit
# international circuit do
# circuit do so
# do so by
# so by progressing
# by progressing through
# progressing through itf
# through itf satellite
# itf satellite future
# satellite future and
# future and challenger
# and challenger tournaments
# challenger tournaments before
# tournaments before entering
# before entering the
# entering the main
# the main circuit
# main circuit .
# circuit . the
# . the latter
# the latter three
# latter three circuits
# three circuits also
# circuits also have
# also have adults
# have adults competing
# adults competing in
# competing in them
# in them .
# them . some
# . some juniors
# some juniors however
# juniors however such
# however such as
# such as australian
# as australian lleyton
# australian lleyton hewitt
# lleyton hewitt and
# hewitt and frenchman
# and frenchman gal
# frenchman gal monfils
# gal monfils have
# monfils have catapulted
# have catapulted directly
# catapulted directly from
# directly from the
# from the junior
# the junior tour
# junior tour to
# tour to the
# to the atp
# the atp tour
# atp tour by
# tour by dominating
# by dominating the
# dominating the junior
# the junior scene
# junior scene or
# scene or by
# or by taking
# by taking advantage
# taking advantage of
# advantage of opportunities
# of opportunities given
# opportunities given to
# given to them
# to them to
# them to participate
# to participate in
# participate in professional
# in professional tournaments.in
# professional tournaments.in the
# tournaments.in the itf
# the itf implemented
# itf implemented a
# implemented a new
# a new rankings
# new rankings scheme
# rankings scheme to
# scheme to encourage
# to encourage greater
# encourage greater participation
# greater participation in
# participation in doubles
# in doubles by
# doubles by combining
# by combining two
# combining two rankings
# two rankings singles
# rankings singles and
# singles and doubles
# and doubles into
# doubles into one
# into one combined
# one combined tally
# combined tally .
# tally . junior
# . junior tournaments
# junior tournaments do
# tournaments do not
# do not offer
# not offer prize
# offer prize money
# prize money except
# money except for
# except for the
# for the grand
# the grand slam
# grand slam tournaments
# slam tournaments which
# tournaments which are
# which are the
# are the most
# the most prestigious
# most prestigious junior
# prestigious junior events
# junior events .
# events . juniors
# . juniors may
# juniors may earn
# may earn income
# earn income from
# income from tennis
# from tennis by
# tennis by participating
# by participating in
# participating in the
# in the future
# the future satellite
# future satellite or
# satellite or challenger
# or challenger tours
# challenger tours .
# tours . tournaments
# . tournaments are
# tournaments are broken
# are broken up
# broken up into
# up into different
# into different tiers
# different tiers offering
# tiers offering different
# offering different amounts
# different amounts of
# amounts of ranking
# of ranking points
# ranking points culminating
# points culminating with
# culminating with grade
# with grade a.leading
# grade a.leading juniors
# a.leading juniors are
# juniors are allowed
# are allowed to
# allowed to participate
# to participate for
# participate for their
# for their nation
# their nation in
# nation in the
# in the junior
# the junior fed
# junior fed cup
# fed cup and
# cup and davis
# and davis cup
# davis cup competitions
# cup competitions .
# competitions . to
# . to succeed
# to succeed in
# succeed in tennis
# in tennis often
# tennis often means
# often means having
# means having to
# having to begin
# to begin playing
# begin playing at
# playing at a
# at a young
# a young age
# young age .
# age . to
# . to facilitate
# to facilitate and
# facilitate and nurture
# and nurture a
# nurture a juniors
# a juniors growth
# juniors growth in
# growth in tennis
# in tennis almost
# tennis almost all
# almost all tennis
# all tennis playing
# tennis playing nations
# playing nations have
# nations have developed
# have developed a
# developed a junior
# a junior development
# junior development system
# development system .
# system . juniors
# . juniors develop
# juniors develop their
# develop their play
# their play through
# play through a
# through a range
# a range of
# range of tournaments
# of tournaments on
# tournaments on all
# on all surfaces
# all surfaces accommodating
# surfaces accommodating all
# accommodating all different
# all different standards
# different standards of
# standards of play
# of play .
# play . talented
# . talented juniors
# talented juniors may
# juniors may also
# may also receive
# also receive sponsorships
# receive sponsorships from
# sponsorships from governing
# from governing bodies
# governing bodies or
# bodies or private
# or private institutions.muscle
# private institutions.muscle strain
# institutions.muscle strain is
# strain is one
# is one of
# one of the
# of the most
# the most common
# most common injuries
# common injuries in
# injuries in tennis
# in tennis .
# tennis . when
# . when an
# when an isolated
# an isolated largeenergy
# isolated largeenergy appears
# largeenergy appears during
# appears during the
# during the muscle
# the muscle contraction
# muscle contraction and
# contraction and at
# and at the
# at the same
# the same time
# same time body
# time body weight
# body weight apply
# weight apply huge
# apply huge amount
# huge amount of
# amount of pressure
# of pressure to
# pressure to the
# to the lengthened
# the lengthened muscle
# lengthened muscle muscle
# muscle muscle strain
# muscle strain can
# strain can occur
# can occur .
# occur . inflammation
# . inflammation and
# inflammation and bleeding
# and bleeding are
# bleeding are triggered
# are triggered when
# triggered when muscle
# when muscle strain
# muscle strain occurs
# strain occurs which
# occurs which can
# which can result
# can result in
# result in redness
# in redness pain
# redness pain and
# pain and swelling
# and swelling .
# swelling . overuse
# . overuse is
# overuse is also
# is also common
# also common in
# common in tennis
# in tennis players
# tennis players of
# players of all
# of all levels
# all levels .
# levels . muscle
# . muscle cartilage
# muscle cartilage nerves
# cartilage nerves bursae
# nerves bursae ligaments
# bursae ligaments and
# ligaments and tendons
# and tendons may
# tendons may be
# may be damaged
# be damaged from
# damaged from overuse
# from overuse .
# overuse . the
# . the repetitive
# the repetitive use
# repetitive use of
# use of a
# of a particular
# a particular muscle
# particular muscle without
# muscle without time
# without time for
# time for repair
# for repair and
# repair and recovery
# and recovery is
# recovery is the
# is the most
# the most common
# most common cause
# common cause of
# cause of injury

# %% [markdown]
# creamos un modelo de trigrama de palabras. El proceso es similar al que se sigue para utilizar trigramas de caracteres. Sin embargo, en el script anterior, primero convertimos nuestro corpus en palabras.
#
# A continuación, iteramos a través de todas las palabras y luego unimos las tres palabras actuales para formar un trigrama. Después de eso, verificamos si la palabra trigrama existe en el ngrams diccionario. Si el trigrama aún no existe, simplemente lo insertamos en el ngrams diccionario como clave.
#
# Finalmente, adjuntamos la lista de palabras que siguen al trigrama en todo el corpus, como valor en el diccionario.
#
# Ahora si miras el ngrams diccionario, en el explorador de variables, se verá así:
#
# Puede ver los trigramas como claves de diccionario y las palabras correspondientes como valores de diccionario.

# %%
curr_sequence=" ".join(words_tokens[0:words])
output = curr_sequence
for i in range(50):
    if curr_sequence not in ngrams.keys():
        break
    possible_words = ngrams[curr_sequence]
    next_word = possible_words[random.randrange(len(possible_words))]
    output += ' ' + next_word
    seq_words = nltk.word_tokenize(output)
    curr_sequence=" ".join(seq_words[len(seq_words)-words:len(seq_words)])

print(output)
# Out:
# tennis is a shot returned to the opponent in midair before the ball is spinning counterclockwise it will curve right from the hitters point of view and curve left if spinning clockwise.some servers are content to use the serve simply to initiate the point however advanced players often try to hit a winning

# %% [markdown]
# en el script anterior, inicializamos el curr_sequence variable con el primer trigrama del corpus. El primer trigrama es «el tenis es un». Generaremos 50 palabras usando el primer trigrama como entrada. Para ello, ejecutamos un ciclo for que se ejecuta 50 veces. Durante cada iteración, primero se comprueba si la palabra trigrama existe en el ngrams diccionario. Si no, el bucle se rompe. De lo contrario, la lista de palabras que probablemente seguirán el trigrama se recuperará del ngrams diccionario pasando trigrama como valor. De la lista de palabras posibles, se elige una palabra al azar y se agrega al final de la salida. Finalmente, el curr_sequence La variable se actualiza con el valor del siguiente trigrama del diccionario.
